# %% [markdown]
# ### 데이터 전처리 및 특징추출
# - 캐글 파일

# %%
import pandas as pd
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import os

# %%
m_files = []
directories = []
for i in os.walk('./data/genres/'):
    for j in i:
        if isinstance(j, list) and j!=[]:
            m_files.append(j)
        elif j:
            directories.append(j)
wave_files = dict(zip(directories[1:], m_files[1:]))

# %%
m_files.remove(['.DS_Store'])

# %%
m_files
# Out:
# [['pop',
#   'metal',
#   'disco',
#   'blues',
#   'reggae',
#   'classical',
#   'rock',
#   'hiphop',
#   'country',
#   'jazz'],
#  ['pop.00080.au',
#   'pop.00022.au',
#   'pop.00073.au',
#   'pop.00047.au',
#   'pop.00016.au',
#   'pop.00006.au',
#   'pop.00057.au',
#   'pop.00063.au',
#   'pop.00032.au',
#   'pop.00090.au',
#   'pop.00012.au',
#   'pop.00043.au',
#   'pop.00084.au',
#   'pop.00077.au',
#   'pop.00026.au',
#   'pop.00036.au',
#   'pop.00067.au',
#   'pop.00094.au',
#   'pop.00053.au',
#   'pop.00002.au',
#   'pop.00013.au',
#   'pop.00042.au',
#   'pop.00085.au',
#   'pop.00076.au',
#   'pop.00027.au',
#   'pop.00037.au',
#   'pop.00066.au',
#   'pop.00095.au',
#   'pop.00052.au',
#   'pop.00003.au',
#   'pop.00081.au',
#   'pop.00023.au',
#   'pop.00072.au',
#   'pop.00046.au',
#   'pop.00017.au',
#   'pop.00007.au',
#   'pop.00056.au',
#   'pop.00062.au',
#   'pop.00033.au',
#   'pop.00091.au',
#   'pop.00028.au',
#   'pop.00079.au',
#   'pop.00069.au',
#   'pop.00038.au',
#   'pop.00018.au',
#   'pop.00049.au',
#   'pop.00059.au',
#   'pop.00008.au',
#   'pop.00019.au',
#   'pop.00048.au',
#   'pop.00058.au',
#   'pop.00009.au',
#   'pop.00029.au',
#   'pop.00078.au',
#   'pop.00068.au',
#   'pop.00039.au',
#   'pop.00088.au',
#   'pop.00098.au',
#   'pop.00089.au',
#   'pop.00099.au',
#   'pop.00041.au',
#   'pop.00010.au',
#   'pop.00024.au',
#   'pop.00075.au',
#   'pop.00086.au',
#   'pop.00096.au',
#   'pop.00065.au',
#   'pop.00034.au',
#   'pop.00000.au',
#   'pop.00051.au',
#   'pop.00071.au',
#   'pop.00020.au',
#   'pop.00082.au',
#   'pop.00014.au',
#   'pop.00045.au',
#   'pop.00055.au',
#   'pop.00004.au',
#   'pop.00092.au',
#   'pop.00030.au',
#   'pop.00061.au',
#   'pop.00070.au',
#   'pop.00021.au',
#   'pop.00083.au',
#   'pop.00015.au',
#   'pop.00044.au',
#   'pop.00054.au',
#   'pop.00005.au',
#   'pop.00093.au',
#   'pop.00031.au',
#   'pop.00060.au',
#   'pop.00040.au',
#   'pop.00011.au',
#   'pop.00025.au',
#   'pop.00074.au',
#   'pop.00087.au',
#   'pop.00097.au',
#   'pop.00064.au',
#   'pop.00035.au',
#   'pop.00001.au',
#   'pop.00050.au'],
#  ['metal.00089.au',
#   'metal.00099.au',
#   'metal.00088.au',
#   'metal.00098.au',
#   'metal.00015.au',
#   'metal.00044.au',
#   'metal.00070.au',
#   'metal.00021.au',
#   'metal.00083.au',
#   'metal.00093.au',
#   'metal.00031.au',
#   'metal.00060.au',
#   'metal.00054.au',
#   'metal.00005.au',
#   'metal.00025.au',
#   'metal.00074.au',
#   'metal.00087.au',
#   'metal.00040.au',
#   'metal.00011.au',
#   'metal.00001.au',
#   'metal.00050.au',
#   'metal.00097.au',
#   'metal.00064.au',
#   'metal.00035.au',
#   'metal.00024.au',
#   'metal.00075.au',
#   'metal.00086.au',
#   'metal.00041.au',
#   'metal.00010.au',
#   'metal.00000.au',
#   'metal.00051.au',
#   'metal.00096.au',
#   'metal.00065.au',
#   'metal.00034.au',
#   'metal.00014.au',
#   'metal.00045.au',
#   'metal.00071.au',
#   'metal.00020.au',
#   'metal.00082.au',
#   'metal.00092.au',
#   'metal.00030.au',
#   'metal.00061.au',
#   'metal.00055.au',
#   'metal.00004.au',
#   'metal.00085.au',
#   'metal.00076.au',
#   'metal.00027.au',
#   'metal.00013.au',
#   'metal.00042.au',
#   'metal.00052.au',
#   'metal.00003.au',
#   'metal.00037.au',
#   'metal.00066.au',
#   'metal.00095.au',
#   'metal.00046.au',
#   'metal.00017.au',
#   'metal.00081.au',
#   'metal.00023.au',
#   'metal.00072.au',
#   'metal.00062.au',
#   'metal.00033.au',
#   'metal.00091.au',
#   'metal.00007.au',
#   'metal.00056.au',
#   'metal.00047.au',
#   'metal.00016.au',
#   'metal.00080.au',
#   'metal.00022.au',
#   'metal.00073.au',
#   'metal.00063.au',
#   'metal.00032.au',
#   'metal.00090.au',
#   'metal.00006.au',
#   'metal.00057.au',
#   'metal.00084.au',
#   'metal.00077.au',
#   'metal.00026.au',
#   'metal.00012.au',
#   'metal.00043.au',
#   'metal.00053.au',
#   'metal.00002.au',
#   'metal.00036.au',
#   'metal.00067.au',
#   'metal.00094.au',
#   'metal.00019.au',
#   'metal.00048.au',
#   'metal.00058.au',
#   'metal.00009.au',
#   'metal.00029.au',
#   'metal.00078.au',
#   'metal.00068.au',
#   'metal.00039.au',
#   'metal.00028.au',
#   'metal.00079.au',
#   'metal.00069.au',
#   'metal.00038.au',
#   'metal.00018.au',
#   'metal.00049.au',
#   'metal.00059.au',
#   'metal.00008.au'],
#  ['disco.00029.au',
#   'disco.00078.au',
#   'disco.00068.au',
#   'disco.00039.au',
#   'disco.00019.au',
#   'disco.00048.au',
#   'disco.00058.au',
#   'disco.00009.au',
#   'disco.00018.au',
#   'disco.00049.au',
#   'disco.00059.au',
#   'disco.00008.au',
#   'disco.00028.au',
#   'disco.00079.au',
#   'disco.00069.au',
#   'disco.00038.au',
#   'disco.00081.au',
#   'disco.00023.au',
#   'disco.00072.au',
#   'disco.00046.au',
#   'disco.00017.au',
#   'disco.00007.au',
#   'disco.00056.au',
#   'disco.00062.au',
#   'disco.00033.au',
#   'disco.00091.au',
#   'disco.00013.au',
#   'disco.00042.au',
#   'disco.00085.au',
#   'disco.00076.au',
#   'disco.00027.au',
#   'disco.00037.au',
#   'disco.00066.au',
#   'disco.00095.au',
#   'disco.00052.au',
#   'disco.00003.au',
#   'disco.00012.au',
#   'disco.00043.au',
#   'disco.00084.au',
#   'disco.00077.au',
#   'disco.00026.au',
#   'disco.00036.au',
#   'disco.00067.au',
#   'disco.00094.au',
#   'disco.00053.au',
#   'disco.00002.au',
#   'disco.00080.au',
#   'disco.00022.au',
#   'disco.00073.au',
#   'disco.00047.au',
#   'disco.00016.au',
#   'disco.00006.au',
#   'disco.00057.au',
#   'disco.00063.au',
#   'disco.00032.au',
#   'disco.00090.au',
#   'disco.00040.au',
#   'disco.00011.au',
#   'disco.00025.au',
#   'disco.00074.au',
#   'disco.00087.au',
#   'disco.00097.au',
#   'disco.00064.au',
#   'disco.00035.au',
#   'disco.00001.au',
#   'disco.00050.au',
#   'disco.00070.au',
#   'disco.00021.au',
#   'disco.00083.au',
#   'disco.00015.au',
#   'disco.00044.au',
#   'disco.00054.au',
#   'disco.00005.au',
#   'disco.00093.au',
#   'disco.00031.au',
#   'disco.00060.au',
#   'disco.00071.au',
#   'disco.00020.au',
#   'disco.00082.au',
#   'disco.00014.au',
#   'disco.00045.au',
#   'disco.00055.au',
#   'disco.00004.au',
#   'disco.00092.au',
#   'disco.00030.au',
#   'disco.00061.au',
#   'disco.00041.au',
#   'disco.00010.au',
#   'disco.00024.au',
#   'disco.00075.au',
#   'disco.00086.au',
#   'disco.00096.au',
#   'disco.00065.au',
#   'disco.00034.au',
#   'disco.00000.au',
#   'disco.00051.au',
#   'disco.00089.au',
#   'disco.00099.au',
#   'disco.00088.au',
#   'disco.00098.au'],
#  ['blues.00043.au',
#   'blues.00012.au',
#   'blues.00026.au',
#   'blues.00077.au',
#   'blues.00084.au',
#   'blues.00094.au',
#   'blues.00067.au',
#   'blues.00036.au',
#   'blues.00002.au',
#   'blues.00053.au',
#   'blues.00073.au',
#   'blues.00022.au',
#   'blues.00080.au',
#   'blues.00016.au',
#   'blues.00047.au',
#   'blues.00057.au',
#   'blues.00006.au',
#   'blues.00090.au',
#   'blues.00032.au',
#   'blues.00063.au',
#   'blues.00072.au',
#   'blues.00023.au',
#   'blues.00081.au',
#   'blues.00017.au',
#   'blues.00046.au',
#   'blues.00056.au',
#   'blues.00007.au',
#   'blues.00091.au',
#   'blues.00033.au',
#   'blues.00062.au',
#   'blues.00042.au',
#   'blues.00013.au',
#   'blues.00027.au',
#   'blues.00076.au',
#   'blues.00085.au',
#   'blues.00095.au',
#   'blues.00066.au',
#   'blues.00037.au',
#   'blues.00003.au',
#   'blues.00052.au',
#   'blues.00049.au',
#   'blues.00018.au',
#   'blues.00008.au',
#   'blues.00059.au',
#   'blues.00079.au',
#   'blues.00028.au',
#   'blues.00038.au',
#   'blues.00069.au',
#   'blues.00078.au',
#   'blues.00029.au',
#   'blues.00039.au',
#   'blues.00068.au',
#   'blues.00048.au',
#   'blues.00019.au',
#   'blues.00009.au',
#   'blues.00058.au',
#   'blues.00088.au',
#   'blues.00098.au',
#   'blues.00089.au',
#   'blues.00099.au',
#   'blues.00082.au',
#   'blues.00020.au',
#   'blues.00071.au',
#   'blues.00045.au',
#   'blues.00014.au',
#   'blues.00004.au',
#   'blues.00055.au',
#   'blues.00061.au',
#   'blues.00030.au',
#   'blues.00092.au',
#   'blues.00010.au',
#   'blues.00041.au',
#   'blues.00086.au',
#   'blues.00075.au',
#   'blues.00024.au',
#   'blues.00034.au',
#   'blues.00065.au',
#   'blues.00096.au',
#   'blues.00051.au',
#   'blues.00000.au',
#   'blues.00011.au',
#   'blues.00040.au',
#   'blues.00087.au',
#   'blues.00074.au',
#   'blues.00025.au',
#   'blues.00035.au',
#   'blues.00064.au',
#   'blues.00097.au',
#   'blues.00050.au',
#   'blues.00001.au',
#   'blues.00083.au',
#   'blues.00021.au',
#   'blues.00070.au',
#   'blues.00044.au',
#   'blues.00015.au',
#   'blues.00005.au',
#   'blues.00054.au',
#   'blues.00060.au',
#   'blues.00031.au',
#   'blues.00093.au'],
#  ['reggae.00031.au',
#   'reggae.00060.au',
#   'reggae.00093.au',
#   'reggae.00054.au',
#   'reggae.00005.au',
#   'reggae.00015.au',
#   'reggae.00044.au',
#   'reggae.00083.au',
#   'reggae.00070.au',
#   'reggae.00021.au',
#   'reggae.00001.au',
#   'reggae.00050.au',
#   'reggae.00064.au',
#   'reggae.00035.au',
#   'reggae.00097.au',
#   'reggae.00087.au',
#   'reggae.00025.au',
#   'reggae.00074.au',
#   'reggae.00040.au',
#   'reggae.00011.au',
#   'reggae.00000.au',
#   'reggae.00051.au',
#   'reggae.00065.au',
#   'reggae.00034.au',
#   'reggae.00096.au',
#   'reggae.00086.au',
#   'reggae.00024.au',
#   'reggae.00075.au',
#   'reggae.00041.au',
#   'reggae.00010.au',
#   'reggae.00030.au',
#   'reggae.00061.au',
#   'reggae.00092.au',
#   'reggae.00055.au',
#   'reggae.00004.au',
#   'reggae.00014.au',
#   'reggae.00045.au',
#   'reggae.00082.au',
#   'reggae.00071.au',
#   'reggae.00020.au',
#   'reggae.00099.au',
#   'reggae.00089.au',
#   'reggae.00098.au',
#   'reggae.00088.au',
#   'reggae.00058.au',
#   'reggae.00009.au',
#   'reggae.00019.au',
#   'reggae.00048.au',
#   'reggae.00068.au',
#   'reggae.00039.au',
#   'reggae.00029.au',
#   'reggae.00078.au',
#   'reggae.00069.au',
#   'reggae.00038.au',
#   'reggae.00028.au',
#   'reggae.00079.au',
#   'reggae.00059.au',
#   'reggae.00008.au',
#   'reggae.00018.au',
#   'reggae.00049.au',
#   'reggae.00052.au',
#   'reggae.00003.au',
#   'reggae.00095.au',
#   'reggae.00037.au',
#   'reggae.00066.au',
#   'reggae.00076.au',
#   'reggae.00027.au',
#   'reggae.00085.au',
#   'reggae.00013.au',
#   'reggae.00042.au',
#   'reggae.00091.au',
#   'reggae.00062.au',
#   'reggae.00033.au',
#   'reggae.00007.au',
#   'reggae.00056.au',
#   'reggae.00046.au',
#   'reggae.00017.au',
#   'reggae.00023.au',
#   'reggae.00072.au',
#   'reggae.00081.au',
#   'reggae.00090.au',
#   'reggae.00063.au',
#   'reggae.00032.au',
#   'reggae.00006.au',
#   'reggae.00057.au',
#   'reggae.00047.au',
#   'reggae.00016.au',
#   'reggae.00022.au',
#   'reggae.00073.au',
#   'reggae.00080.au',
#   'reggae.00053.au',
#   'reggae.00002.au',
#   'reggae.00094.au',
#   'reggae.00036.au',
#   'reggae.00067.au',
#   'reggae.00077.au',
#   'reggae.00026.au',
#   'reggae.00084.au',
#   'reggae.00012.au',
#   'reggae.00043.au'],
#  ['classical.00097.au',
#   'classical.00064.au',
#   'classical.00035.au',
#   'classical.00001.au',
#   'classical.00050.au',
#   'classical.00040.au',
#   'classical.00011.au',
#   'classical.00025.au',
#   'classical.00074.au',
#   'classical.00087.au',
#   'classical.00054.au',
#   'classical.00005.au',
#   'classical.00093.au',
#   'classical.00031.au',
#   'classical.00060.au',
#   'classical.00070.au',
#   'classical.00021.au',
#   'classical.00083.au',
#   'classical.00015.au',
#   'classical.00044.au',
#   'classical.00055.au',
#   'classical.00004.au',
#   'classical.00092.au',
#   'classical.00030.au',
#   'classical.00061.au',
#   'classical.00071.au',
#   'classical.00020.au',
#   'classical.00082.au',
#   'classical.00014.au',
#   'classical.00045.au',
#   'classical.00096.au',
#   'classical.00065.au',
#   'classical.00034.au',
#   'classical.00000.au',
#   'classical.00051.au',
#   'classical.00041.au',
#   'classical.00010.au',
#   'classical.00024.au',
#   'classical.00075.au',
#   'classical.00086.au',
#   'classical.00099.au',
#   'classical.00089.au',
#   'classical.00098.au',
#   'classical.00088.au',
#   'classical.00068.au',
#   'classical.00039.au',
#   'classical.00029.au',
#   'classical.00078.au',
#   'classical.00058.au',
#   'classical.00009.au',
#   'classical.00019.au',
#   'classical.00048.au',
#   'classical.00059.au',
#   'classical.00008.au',
#   'classical.00018.au',
#   'classical.00049.au',
#   'classical.00069.au',
#   'classical.00038.au',
#   'classical.00028.au',
#   'classical.00079.au',
#   'classical.00007.au',
#   'classical.00056.au',
#   'classical.00062.au',
#   'classical.00033.au',
#   'classical.00091.au',
#   'classical.00081.au',
#   'classical.00023.au',
#   'classical.00072.au',
#   'classical.00046.au',
#   'classical.00017.au',
#   'classical.00037.au',
#   'classical.00066.au',
#   'classical.00095.au',
#   'classical.00052.au',
#   'classical.00003.au',
#   'classical.00013.au',
#   'classical.00042.au',
#   'classical.00085.au',
#   'classical.00076.au',
#   'classical.00027.au',
#   'classical.00036.au',
#   'classical.00067.au',
#   'classical.00094.au',
#   'classical.00053.au',
#   'classical.00002.au',
#   'classical.00012.au',
#   'classical.00043.au',
#   'classical.00084.au',
#   'classical.00077.au',
#   'classical.00026.au',
#   'classical.00006.au',
#   'classical.00057.au',
#   'classical.00063.au',
#   'classical.00032.au',
#   'classical.00090.au',
#   'classical.00080.au',
#   'classical.00022.au',
#   'classical.00073.au',
#   'classical.00047.au',
#   'classical.00016.au'],
#  ['rock.00039.au',
#   'rock.00068.au',
#   'rock.00078.au',
#   'rock.00029.au',
#   'rock.00009.au',
#   'rock.00058.au',
#   'rock.00048.au',
#   'rock.00019.au',
#   'rock.00008.au',
#   'rock.00059.au',
#   'rock.00049.au',
#   'rock.00018.au',
#   'rock.00038.au',
#   'rock.00069.au',
#   'rock.00079.au',
#   'rock.00028.au',
#   'rock.00091.au',
#   'rock.00033.au',
#   'rock.00062.au',
#   'rock.00056.au',
#   'rock.00007.au',
#   'rock.00017.au',
#   'rock.00046.au',
#   'rock.00072.au',
#   'rock.00023.au',
#   'rock.00081.au',
#   'rock.00003.au',
#   'rock.00052.au',
#   'rock.00095.au',
#   'rock.00066.au',
#   'rock.00037.au',
#   'rock.00027.au',
#   'rock.00076.au',
#   'rock.00085.au',
#   'rock.00042.au',
#   'rock.00013.au',
#   'rock.00002.au',
#   'rock.00053.au',
#   'rock.00094.au',
#   'rock.00067.au',
#   'rock.00036.au',
#   'rock.00026.au',
#   'rock.00077.au',
#   'rock.00084.au',
#   'rock.00043.au',
#   'rock.00012.au',
#   'rock.00090.au',
#   'rock.00032.au',
#   'rock.00063.au',
#   'rock.00057.au',
#   'rock.00006.au',
#   'rock.00016.au',
#   'rock.00047.au',
#   'rock.00073.au',
#   'rock.00022.au',
#   'rock.00080.au',
#   'rock.00050.au',
#   'rock.00001.au',
#   'rock.00035.au',
#   'rock.00064.au',
#   'rock.00097.au',
#   'rock.00087.au',
#   'rock.00074.au',
#   'rock.00025.au',
#   'rock.00011.au',
#   'rock.00040.au',
#   'rock.00060.au',
#   'rock.00031.au',
#   'rock.00093.au',
#   'rock.00005.au',
#   'rock.00054.au',
#   'rock.00044.au',
#   'rock.00015.au',
#   'rock.00083.au',
#   'rock.00021.au',
#   'rock.00070.au',
#   'rock.00061.au',
#   'rock.00030.au',
#   'rock.00092.au',
#   'rock.00004.au',
#   'rock.00055.au',
#   'rock.00045.au',
#   'rock.00014.au',
#   'rock.00082.au',
#   'rock.00020.au',
#   'rock.00071.au',
#   'rock.00051.au',
#   'rock.00000.au',
#   'rock.00034.au',
#   'rock.00065.au',
#   'rock.00096.au',
#   'rock.00086.au',
#   'rock.00075.au',
#   'rock.00024.au',
#   'rock.00010.au',
#   'rock.00041.au',
#   'rock.00099.au',
#   'rock.00089.au',
#   'rock.00098.au',
#   'rock.00088.au'],
#  ['hiphop.00017.au',
#   'hiphop.00046.au',
#   'hiphop.00072.au',
#   'hiphop.00023.au',
#   'hiphop.00081.au',
#   'hiphop.00091.au',
#   'hiphop.00033.au',
#   'hiphop.00062.au',
#   'hiphop.00056.au',
#   'hiphop.00007.au',
#   'hiphop.00027.au',
#   'hiphop.00076.au',
#   'hiphop.00085.au',
#   'hiphop.00042.au',
#   'hiphop.00013.au',
#   'hiphop.00003.au',
#   'hiphop.00052.au',
#   'hiphop.00095.au',
#   'hiphop.00066.au',
#   'hiphop.00037.au',
#   'hiphop.00026.au',
#   'hiphop.00077.au',
#   'hiphop.00084.au',
#   'hiphop.00043.au',
#   'hiphop.00012.au',
#   'hiphop.00002.au',
#   'hiphop.00053.au',
#   'hiphop.00094.au',
#   'hiphop.00067.au',
#   'hiphop.00036.au',
#   'hiphop.00016.au',
#   'hiphop.00047.au',
#   'hiphop.00073.au',
#   'hiphop.00022.au',
#   'hiphop.00080.au',
#   'hiphop.00090.au',
#   'hiphop.00032.au',
#   'hiphop.00063.au',
#   'hiphop.00057.au',
#   'hiphop.00006.au',
#   'hiphop.00078.au',
#   'hiphop.00029.au',
#   'hiphop.00039.au',
#   'hiphop.00068.au',
#   'hiphop.00048.au',
#   'hiphop.00019.au',
#   'hiphop.00009.au',
#   'hiphop.00058.au',
#   'hiphop.00049.au',
#   'hiphop.00018.au',
#   'hiphop.00008.au',
#   'hiphop.00059.au',
#   'hiphop.00079.au',
#   'hiphop.00028.au',
#   'hiphop.00038.au',
#   'hiphop.00069.au',
#   'hiphop.00089.au',
#   'hiphop.00099.au',
#   'hiphop.00088.au',
#   'hiphop.00098.au',
#   'hiphop.00087.au',
#   'hiphop.00074.au',
#   'hiphop.00025.au',
#   'hiphop.00011.au',
#   'hiphop.00040.au',
#   'hiphop.00050.au',
#   'hiphop.00001.au',
#   'hiphop.00035.au',
#   'hiphop.00064.au',
#   'hiphop.00097.au',
#   'hiphop.00044.au',
#   'hiphop.00015.au',
#   'hiphop.00083.au',
#   'hiphop.00021.au',
#   'hiphop.00070.au',
#   'hiphop.00060.au',
#   'hiphop.00031.au',
#   'hiphop.00093.au',
#   'hiphop.00005.au',
#   'hiphop.00054.au',
#   'hiphop.00045.au',
#   'hiphop.00014.au',
#   'hiphop.00082.au',
#   'hiphop.00020.au',
#   'hiphop.00071.au',
#   'hiphop.00061.au',
#   'hiphop.00030.au',
#   'hiphop.00092.au',
#   'hiphop.00004.au',
#   'hiphop.00055.au',
#   'hiphop.00086.au',
#   'hiphop.00075.au',
#   'hiphop.00024.au',
#   'hiphop.00010.au',
#   'hiphop.00041.au',
#   'hiphop.00051.au',
#   'hiphop.00000.au',
#   'hiphop.00034.au',
#   'hiphop.00065.au',
#   'hiphop.00096.au'],
#  ['country.00058.au',
#   'country.00009.au',
#   'country.00019.au',
#   'country.00048.au',
#   'country.00068.au',
#   'country.00039.au',
#   'country.00029.au',
#   'country.00078.au',
#   'country.00069.au',
#   'country.00038.au',
#   'country.00028.au',
#   'country.00079.au',
#   'country.00059.au',
#   'country.00008.au',
#   'country.00018.au',
#   'country.00049.au',
#   'country.00095.au',
#   'country.00037.au',
#   'country.00066.au',
#   'country.00052.au',
#   'country.00003.au',
#   'country.00013.au',
#   'country.00042.au',
#   'country.00076.au',
#   'country.00027.au',
#   'country.00085.au',
#   'country.00007.au',
#   'country.00056.au',
#   'country.00091.au',
#   'country.00062.au',
#   'country.00033.au',
#   'country.00023.au',
#   'country.00072.au',
#   'country.00081.au',
#   'country.00046.au',
#   'country.00017.au',
#   'country.00006.au',
#   'country.00057.au',
#   'country.00090.au',
#   'country.00063.au',
#   'country.00032.au',
#   'country.00022.au',
#   'country.00073.au',
#   'country.00080.au',
#   'country.00047.au',
#   'country.00016.au',
#   'country.00094.au',
#   'country.00036.au',
#   'country.00067.au',
#   'country.00053.au',
#   'country.00002.au',
#   'country.00012.au',
#   'country.00043.au',
#   'country.00077.au',
#   'country.00026.au',
#   'country.00084.au',
#   'country.00054.au',
#   'country.00005.au',
#   'country.00031.au',
#   'country.00060.au',
#   'country.00093.au',
#   'country.00083.au',
#   'country.00070.au',
#   'country.00021.au',
#   'country.00015.au',
#   'country.00044.au',
#   'country.00064.au',
#   'country.00035.au',
#   'country.00097.au',
#   'country.00001.au',
#   'country.00050.au',
#   'country.00040.au',
#   'country.00011.au',
#   'country.00087.au',
#   'country.00025.au',
#   'country.00074.au',
#   'country.00065.au',
#   'country.00034.au',
#   'country.00096.au',
#   'country.00000.au',
#   'country.00051.au',
#   'country.00041.au',
#   'country.00010.au',
#   'country.00086.au',
#   'country.00024.au',
#   'country.00075.au',
#   'country.00055.au',
#   'country.00004.au',
#   'country.00030.au',
#   'country.00061.au',
#   'country.00092.au',
#   'country.00082.au',
#   'country.00071.au',
#   'country.00020.au',
#   'country.00014.au',
#   'country.00045.au',
#   'country.00099.au',
#   'country.00089.au',
#   'country.00098.au',
#   'country.00088.au'],
#  ['jazz.00061.au',
#   'jazz.00030.au',
#   'jazz.00092.au',
#   'jazz.00004.au',
#   'jazz.00055.au',
#   'jazz.00045.au',
#   'jazz.00014.au',
#   'jazz.00082.au',
#   'jazz.00020.au',
#   'jazz.00071.au',
#   'jazz.00051.au',
#   'jazz.00000.au',
#   'jazz.00034.au',
#   'jazz.00065.au',
#   'jazz.00096.au',
#   'jazz.00086.au',
#   'jazz.00075.au',
#   'jazz.00024.au',
#   'jazz.00010.au',
#   'jazz.00041.au',
#   'jazz.00050.au',
#   'jazz.00001.au',
#   'jazz.00035.au',
#   'jazz.00064.au',
#   'jazz.00097.au',
#   'jazz.00087.au',
#   'jazz.00074.au',
#   'jazz.00025.au',
#   'jazz.00011.au',
#   'jazz.00040.au',
#   'jazz.00060.au',
#   'jazz.00031.au',
#   'jazz.00093.au',
#   'jazz.00005.au',
#   'jazz.00054.au',
#   'jazz.00044.au',
#   'jazz.00015.au',
#   'jazz.00083.au',
#   'jazz.00021.au',
#   'jazz.00070.au',
#   'jazz.00098.au',
#   'jazz.00088.au',
#   'jazz.00099.au',
#   'jazz.00089.au',
#   'jazz.00008.au',
#   'jazz.00059.au',
#   'jazz.00049.au',
#   'jazz.00018.au',
#   'jazz.00038.au',
#   'jazz.00069.au',
#   'jazz.00079.au',
#   'jazz.00028.au',
#   'jazz.00039.au',
#   'jazz.00068.au',
#   'jazz.00078.au',
#   'jazz.00029.au',
#   'jazz.00009.au',
#   'jazz.00058.au',
#   'jazz.00048.au',
#   'jazz.00019.au',
#   'jazz.00002.au',
#   'jazz.00053.au',
#   'jazz.00094.au',
#   'jazz.00067.au',
#   'jazz.00036.au',
#   'jazz.00026.au',
#   'jazz.00077.au',
#   'jazz.00084.au',
#   'jazz.00043.au',
#   'jazz.00012.au',
#   'jazz.00090.au',
#   'jazz.00032.au',
#   'jazz.00063.au',
#   'jazz.00057.au',
#   'jazz.00006.au',
#   'jazz.00016.au',
#   'jazz.00047.au',
#   'jazz.00073.au',
#   'jazz.00022.au',
#   'jazz.00080.au',
#   'jazz.00091.au',
#   'jazz.00033.au',
#   'jazz.00062.au',
#   'jazz.00056.au',
#   'jazz.00007.au',
#   'jazz.00017.au',
#   'jazz.00046.au',
#   'jazz.00072.au',
#   'jazz.00023.au',
#   'jazz.00081.au',
#   'jazz.00003.au',
#   'jazz.00052.au',
#   'jazz.00095.au',
#   'jazz.00066.au',
#   'jazz.00037.au',
#   'jazz.00027.au',
#   'jazz.00076.au',
#   'jazz.00085.au',
#   'jazz.00042.au',
#   'jazz.00013.au']]

# %%
directories
# Out:
# ['./data/genres/',
#  './data/genres/pop',
#  './data/genres/metal',
#  './data/genres/disco',
#  './data/genres/blues',
#  './data/genres/reggae',
#  './data/genres/classical',
#  './data/genres/rock',
#  './data/genres/hiphop',
#  './data/genres/country',
#  './data/genres/jazz']

# %%
len(wave_files)
# Out:
# 10

# %%
wave_files = dict(zip(directories[1:], m_files[1:]))

# %%
wave_files
# Out:
# {'./data/genres/pop': ['pop.00080.au',
#   'pop.00022.au',
#   'pop.00073.au',
#   'pop.00047.au',
#   'pop.00016.au',
#   'pop.00006.au',
#   'pop.00057.au',
#   'pop.00063.au',
#   'pop.00032.au',
#   'pop.00090.au',
#   'pop.00012.au',
#   'pop.00043.au',
#   'pop.00084.au',
#   'pop.00077.au',
#   'pop.00026.au',
#   'pop.00036.au',
#   'pop.00067.au',
#   'pop.00094.au',
#   'pop.00053.au',
#   'pop.00002.au',
#   'pop.00013.au',
#   'pop.00042.au',
#   'pop.00085.au',
#   'pop.00076.au',
#   'pop.00027.au',
#   'pop.00037.au',
#   'pop.00066.au',
#   'pop.00095.au',
#   'pop.00052.au',
#   'pop.00003.au',
#   'pop.00081.au',
#   'pop.00023.au',
#   'pop.00072.au',
#   'pop.00046.au',
#   'pop.00017.au',
#   'pop.00007.au',
#   'pop.00056.au',
#   'pop.00062.au',
#   'pop.00033.au',
#   'pop.00091.au',
#   'pop.00028.au',
#   'pop.00079.au',
#   'pop.00069.au',
#   'pop.00038.au',
#   'pop.00018.au',
#   'pop.00049.au',
#   'pop.00059.au',
#   'pop.00008.au',
#   'pop.00019.au',
#   'pop.00048.au',
#   'pop.00058.au',
#   'pop.00009.au',
#   'pop.00029.au',
#   'pop.00078.au',
#   'pop.00068.au',
#   'pop.00039.au',
#   'pop.00088.au',
#   'pop.00098.au',
#   'pop.00089.au',
#   'pop.00099.au',
#   'pop.00041.au',
#   'pop.00010.au',
#   'pop.00024.au',
#   'pop.00075.au',
#   'pop.00086.au',
#   'pop.00096.au',
#   'pop.00065.au',
#   'pop.00034.au',
#   'pop.00000.au',
#   'pop.00051.au',
#   'pop.00071.au',
#   'pop.00020.au',
#   'pop.00082.au',
#   'pop.00014.au',
#   'pop.00045.au',
#   'pop.00055.au',
#   'pop.00004.au',
#   'pop.00092.au',
#   'pop.00030.au',
#   'pop.00061.au',
#   'pop.00070.au',
#   'pop.00021.au',
#   'pop.00083.au',
#   'pop.00015.au',
#   'pop.00044.au',
#   'pop.00054.au',
#   'pop.00005.au',
#   'pop.00093.au',
#   'pop.00031.au',
#   'pop.00060.au',
#   'pop.00040.au',
#   'pop.00011.au',
#   'pop.00025.au',
#   'pop.00074.au',
#   'pop.00087.au',
#   'pop.00097.au',
#   'pop.00064.au',
#   'pop.00035.au',
#   'pop.00001.au',
#   'pop.00050.au'],
#  './data/genres/metal': ['metal.00089.au',
#   'metal.00099.au',
#   'metal.00088.au',
#   'metal.00098.au',
#   'metal.00015.au',
#   'metal.00044.au',
#   'metal.00070.au',
#   'metal.00021.au',
#   'metal.00083.au',
#   'metal.00093.au',
#   'metal.00031.au',
#   'metal.00060.au',
#   'metal.00054.au',
#   'metal.00005.au',
#   'metal.00025.au',
#   'metal.00074.au',
#   'metal.00087.au',
#   'metal.00040.au',
#   'metal.00011.au',
#   'metal.00001.au',
#   'metal.00050.au',
#   'metal.00097.au',
#   'metal.00064.au',
#   'metal.00035.au',
#   'metal.00024.au',
#   'metal.00075.au',
#   'metal.00086.au',
#   'metal.00041.au',
#   'metal.00010.au',
#   'metal.00000.au',
#   'metal.00051.au',
#   'metal.00096.au',
#   'metal.00065.au',
#   'metal.00034.au',
#   'metal.00014.au',
#   'metal.00045.au',
#   'metal.00071.au',
#   'metal.00020.au',
#   'metal.00082.au',
#   'metal.00092.au',
#   'metal.00030.au',
#   'metal.00061.au',
#   'metal.00055.au',
#   'metal.00004.au',
#   'metal.00085.au',
#   'metal.00076.au',
#   'metal.00027.au',
#   'metal.00013.au',
#   'metal.00042.au',
#   'metal.00052.au',
#   'metal.00003.au',
#   'metal.00037.au',
#   'metal.00066.au',
#   'metal.00095.au',
#   'metal.00046.au',
#   'metal.00017.au',
#   'metal.00081.au',
#   'metal.00023.au',
#   'metal.00072.au',
#   'metal.00062.au',
#   'metal.00033.au',
#   'metal.00091.au',
#   'metal.00007.au',
#   'metal.00056.au',
#   'metal.00047.au',
#   'metal.00016.au',
#   'metal.00080.au',
#   'metal.00022.au',
#   'metal.00073.au',
#   'metal.00063.au',
#   'metal.00032.au',
#   'metal.00090.au',
#   'metal.00006.au',
#   'metal.00057.au',
#   'metal.00084.au',
#   'metal.00077.au',
#   'metal.00026.au',
#   'metal.00012.au',
#   'metal.00043.au',
#   'metal.00053.au',
#   'metal.00002.au',
#   'metal.00036.au',
#   'metal.00067.au',
#   'metal.00094.au',
#   'metal.00019.au',
#   'metal.00048.au',
#   'metal.00058.au',
#   'metal.00009.au',
#   'metal.00029.au',
#   'metal.00078.au',
#   'metal.00068.au',
#   'metal.00039.au',
#   'metal.00028.au',
#   'metal.00079.au',
#   'metal.00069.au',
#   'metal.00038.au',
#   'metal.00018.au',
#   'metal.00049.au',
#   'metal.00059.au',
#   'metal.00008.au'],
#  './data/genres/disco': ['disco.00029.au',
#   'disco.00078.au',
#   'disco.00068.au',
#   'disco.00039.au',
#   'disco.00019.au',
#   'disco.00048.au',
#   'disco.00058.au',
#   'disco.00009.au',
#   'disco.00018.au',
#   'disco.00049.au',
#   'disco.00059.au',
#   'disco.00008.au',
#   'disco.00028.au',
#   'disco.00079.au',
#   'disco.00069.au',
#   'disco.00038.au',
#   'disco.00081.au',
#   'disco.00023.au',
#   'disco.00072.au',
#   'disco.00046.au',
#   'disco.00017.au',
#   'disco.00007.au',
#   'disco.00056.au',
#   'disco.00062.au',
#   'disco.00033.au',
#   'disco.00091.au',
#   'disco.00013.au',
#   'disco.00042.au',
#   'disco.00085.au',
#   'disco.00076.au',
#   'disco.00027.au',
#   'disco.00037.au',
#   'disco.00066.au',
#   'disco.00095.au',
#   'disco.00052.au',
#   'disco.00003.au',
#   'disco.00012.au',
#   'disco.00043.au',
#   'disco.00084.au',
#   'disco.00077.au',
#   'disco.00026.au',
#   'disco.00036.au',
#   'disco.00067.au',
#   'disco.00094.au',
#   'disco.00053.au',
#   'disco.00002.au',
#   'disco.00080.au',
#   'disco.00022.au',
#   'disco.00073.au',
#   'disco.00047.au',
#   'disco.00016.au',
#   'disco.00006.au',
#   'disco.00057.au',
#   'disco.00063.au',
#   'disco.00032.au',
#   'disco.00090.au',
#   'disco.00040.au',
#   'disco.00011.au',
#   'disco.00025.au',
#   'disco.00074.au',
#   'disco.00087.au',
#   'disco.00097.au',
#   'disco.00064.au',
#   'disco.00035.au',
#   'disco.00001.au',
#   'disco.00050.au',
#   'disco.00070.au',
#   'disco.00021.au',
#   'disco.00083.au',
#   'disco.00015.au',
#   'disco.00044.au',
#   'disco.00054.au',
#   'disco.00005.au',
#   'disco.00093.au',
#   'disco.00031.au',
#   'disco.00060.au',
#   'disco.00071.au',
#   'disco.00020.au',
#   'disco.00082.au',
#   'disco.00014.au',
#   'disco.00045.au',
#   'disco.00055.au',
#   'disco.00004.au',
#   'disco.00092.au',
#   'disco.00030.au',
#   'disco.00061.au',
#   'disco.00041.au',
#   'disco.00010.au',
#   'disco.00024.au',
#   'disco.00075.au',
#   'disco.00086.au',
#   'disco.00096.au',
#   'disco.00065.au',
#   'disco.00034.au',
#   'disco.00000.au',
#   'disco.00051.au',
#   'disco.00089.au',
#   'disco.00099.au',
#   'disco.00088.au',
#   'disco.00098.au'],
#  './data/genres/blues': ['blues.00043.au',
#   'blues.00012.au',
#   'blues.00026.au',
#   'blues.00077.au',
#   'blues.00084.au',
#   'blues.00094.au',
#   'blues.00067.au',
#   'blues.00036.au',
#   'blues.00002.au',
#   'blues.00053.au',
#   'blues.00073.au',
#   'blues.00022.au',
#   'blues.00080.au',
#   'blues.00016.au',
#   'blues.00047.au',
#   'blues.00057.au',
#   'blues.00006.au',
#   'blues.00090.au',
#   'blues.00032.au',
#   'blues.00063.au',
#   'blues.00072.au',
#   'blues.00023.au',
#   'blues.00081.au',
#   'blues.00017.au',
#   'blues.00046.au',
#   'blues.00056.au',
#   'blues.00007.au',
#   'blues.00091.au',
#   'blues.00033.au',
#   'blues.00062.au',
#   'blues.00042.au',
#   'blues.00013.au',
#   'blues.00027.au',
#   'blues.00076.au',
#   'blues.00085.au',
#   'blues.00095.au',
#   'blues.00066.au',
#   'blues.00037.au',
#   'blues.00003.au',
#   'blues.00052.au',
#   'blues.00049.au',
#   'blues.00018.au',
#   'blues.00008.au',
#   'blues.00059.au',
#   'blues.00079.au',
#   'blues.00028.au',
#   'blues.00038.au',
#   'blues.00069.au',
#   'blues.00078.au',
#   'blues.00029.au',
#   'blues.00039.au',
#   'blues.00068.au',
#   'blues.00048.au',
#   'blues.00019.au',
#   'blues.00009.au',
#   'blues.00058.au',
#   'blues.00088.au',
#   'blues.00098.au',
#   'blues.00089.au',
#   'blues.00099.au',
#   'blues.00082.au',
#   'blues.00020.au',
#   'blues.00071.au',
#   'blues.00045.au',
#   'blues.00014.au',
#   'blues.00004.au',
#   'blues.00055.au',
#   'blues.00061.au',
#   'blues.00030.au',
#   'blues.00092.au',
#   'blues.00010.au',
#   'blues.00041.au',
#   'blues.00086.au',
#   'blues.00075.au',
#   'blues.00024.au',
#   'blues.00034.au',
#   'blues.00065.au',
#   'blues.00096.au',
#   'blues.00051.au',
#   'blues.00000.au',
#   'blues.00011.au',
#   'blues.00040.au',
#   'blues.00087.au',
#   'blues.00074.au',
#   'blues.00025.au',
#   'blues.00035.au',
#   'blues.00064.au',
#   'blues.00097.au',
#   'blues.00050.au',
#   'blues.00001.au',
#   'blues.00083.au',
#   'blues.00021.au',
#   'blues.00070.au',
#   'blues.00044.au',
#   'blues.00015.au',
#   'blues.00005.au',
#   'blues.00054.au',
#   'blues.00060.au',
#   'blues.00031.au',
#   'blues.00093.au'],
#  './data/genres/reggae': ['reggae.00031.au',
#   'reggae.00060.au',
#   'reggae.00093.au',
#   'reggae.00054.au',
#   'reggae.00005.au',
#   'reggae.00015.au',
#   'reggae.00044.au',
#   'reggae.00083.au',
#   'reggae.00070.au',
#   'reggae.00021.au',
#   'reggae.00001.au',
#   'reggae.00050.au',
#   'reggae.00064.au',
#   'reggae.00035.au',
#   'reggae.00097.au',
#   'reggae.00087.au',
#   'reggae.00025.au',
#   'reggae.00074.au',
#   'reggae.00040.au',
#   'reggae.00011.au',
#   'reggae.00000.au',
#   'reggae.00051.au',
#   'reggae.00065.au',
#   'reggae.00034.au',
#   'reggae.00096.au',
#   'reggae.00086.au',
#   'reggae.00024.au',
#   'reggae.00075.au',
#   'reggae.00041.au',
#   'reggae.00010.au',
#   'reggae.00030.au',
#   'reggae.00061.au',
#   'reggae.00092.au',
#   'reggae.00055.au',
#   'reggae.00004.au',
#   'reggae.00014.au',
#   'reggae.00045.au',
#   'reggae.00082.au',
#   'reggae.00071.au',
#   'reggae.00020.au',
#   'reggae.00099.au',
#   'reggae.00089.au',
#   'reggae.00098.au',
#   'reggae.00088.au',
#   'reggae.00058.au',
#   'reggae.00009.au',
#   'reggae.00019.au',
#   'reggae.00048.au',
#   'reggae.00068.au',
#   'reggae.00039.au',
#   'reggae.00029.au',
#   'reggae.00078.au',
#   'reggae.00069.au',
#   'reggae.00038.au',
#   'reggae.00028.au',
#   'reggae.00079.au',
#   'reggae.00059.au',
#   'reggae.00008.au',
#   'reggae.00018.au',
#   'reggae.00049.au',
#   'reggae.00052.au',
#   'reggae.00003.au',
#   'reggae.00095.au',
#   'reggae.00037.au',
#   'reggae.00066.au',
#   'reggae.00076.au',
#   'reggae.00027.au',
#   'reggae.00085.au',
#   'reggae.00013.au',
#   'reggae.00042.au',
#   'reggae.00091.au',
#   'reggae.00062.au',
#   'reggae.00033.au',
#   'reggae.00007.au',
#   'reggae.00056.au',
#   'reggae.00046.au',
#   'reggae.00017.au',
#   'reggae.00023.au',
#   'reggae.00072.au',
#   'reggae.00081.au',
#   'reggae.00090.au',
#   'reggae.00063.au',
#   'reggae.00032.au',
#   'reggae.00006.au',
#   'reggae.00057.au',
#   'reggae.00047.au',
#   'reggae.00016.au',
#   'reggae.00022.au',
#   'reggae.00073.au',
#   'reggae.00080.au',
#   'reggae.00053.au',
#   'reggae.00002.au',
#   'reggae.00094.au',
#   'reggae.00036.au',
#   'reggae.00067.au',
#   'reggae.00077.au',
#   'reggae.00026.au',
#   'reggae.00084.au',
#   'reggae.00012.au',
#   'reggae.00043.au'],
#  './data/genres/classical': ['classical.00097.au',
#   'classical.00064.au',
#   'classical.00035.au',
#   'classical.00001.au',
#   'classical.00050.au',
#   'classical.00040.au',
#   'classical.00011.au',
#   'classical.00025.au',
#   'classical.00074.au',
#   'classical.00087.au',
#   'classical.00054.au',
#   'classical.00005.au',
#   'classical.00093.au',
#   'classical.00031.au',
#   'classical.00060.au',
#   'classical.00070.au',
#   'classical.00021.au',
#   'classical.00083.au',
#   'classical.00015.au',
#   'classical.00044.au',
#   'classical.00055.au',
#   'classical.00004.au',
#   'classical.00092.au',
#   'classical.00030.au',
#   'classical.00061.au',
#   'classical.00071.au',
#   'classical.00020.au',
#   'classical.00082.au',
#   'classical.00014.au',
#   'classical.00045.au',
#   'classical.00096.au',
#   'classical.00065.au',
#   'classical.00034.au',
#   'classical.00000.au',
#   'classical.00051.au',
#   'classical.00041.au',
#   'classical.00010.au',
#   'classical.00024.au',
#   'classical.00075.au',
#   'classical.00086.au',
#   'classical.00099.au',
#   'classical.00089.au',
#   'classical.00098.au',
#   'classical.00088.au',
#   'classical.00068.au',
#   'classical.00039.au',
#   'classical.00029.au',
#   'classical.00078.au',
#   'classical.00058.au',
#   'classical.00009.au',
#   'classical.00019.au',
#   'classical.00048.au',
#   'classical.00059.au',
#   'classical.00008.au',
#   'classical.00018.au',
#   'classical.00049.au',
#   'classical.00069.au',
#   'classical.00038.au',
#   'classical.00028.au',
#   'classical.00079.au',
#   'classical.00007.au',
#   'classical.00056.au',
#   'classical.00062.au',
#   'classical.00033.au',
#   'classical.00091.au',
#   'classical.00081.au',
#   'classical.00023.au',
#   'classical.00072.au',
#   'classical.00046.au',
#   'classical.00017.au',
#   'classical.00037.au',
#   'classical.00066.au',
#   'classical.00095.au',
#   'classical.00052.au',
#   'classical.00003.au',
#   'classical.00013.au',
#   'classical.00042.au',
#   'classical.00085.au',
#   'classical.00076.au',
#   'classical.00027.au',
#   'classical.00036.au',
#   'classical.00067.au',
#   'classical.00094.au',
#   'classical.00053.au',
#   'classical.00002.au',
#   'classical.00012.au',
#   'classical.00043.au',
#   'classical.00084.au',
#   'classical.00077.au',
#   'classical.00026.au',
#   'classical.00006.au',
#   'classical.00057.au',
#   'classical.00063.au',
#   'classical.00032.au',
#   'classical.00090.au',
#   'classical.00080.au',
#   'classical.00022.au',
#   'classical.00073.au',
#   'classical.00047.au',
#   'classical.00016.au'],
#  './data/genres/rock': ['rock.00039.au',
#   'rock.00068.au',
#   'rock.00078.au',
#   'rock.00029.au',
#   'rock.00009.au',
#   'rock.00058.au',
#   'rock.00048.au',
#   'rock.00019.au',
#   'rock.00008.au',
#   'rock.00059.au',
#   'rock.00049.au',
#   'rock.00018.au',
#   'rock.00038.au',
#   'rock.00069.au',
#   'rock.00079.au',
#   'rock.00028.au',
#   'rock.00091.au',
#   'rock.00033.au',
#   'rock.00062.au',
#   'rock.00056.au',
#   'rock.00007.au',
#   'rock.00017.au',
#   'rock.00046.au',
#   'rock.00072.au',
#   'rock.00023.au',
#   'rock.00081.au',
#   'rock.00003.au',
#   'rock.00052.au',
#   'rock.00095.au',
#   'rock.00066.au',
#   'rock.00037.au',
#   'rock.00027.au',
#   'rock.00076.au',
#   'rock.00085.au',
#   'rock.00042.au',
#   'rock.00013.au',
#   'rock.00002.au',
#   'rock.00053.au',
#   'rock.00094.au',
#   'rock.00067.au',
#   'rock.00036.au',
#   'rock.00026.au',
#   'rock.00077.au',
#   'rock.00084.au',
#   'rock.00043.au',
#   'rock.00012.au',
#   'rock.00090.au',
#   'rock.00032.au',
#   'rock.00063.au',
#   'rock.00057.au',
#   'rock.00006.au',
#   'rock.00016.au',
#   'rock.00047.au',
#   'rock.00073.au',
#   'rock.00022.au',
#   'rock.00080.au',
#   'rock.00050.au',
#   'rock.00001.au',
#   'rock.00035.au',
#   'rock.00064.au',
#   'rock.00097.au',
#   'rock.00087.au',
#   'rock.00074.au',
#   'rock.00025.au',
#   'rock.00011.au',
#   'rock.00040.au',
#   'rock.00060.au',
#   'rock.00031.au',
#   'rock.00093.au',
#   'rock.00005.au',
#   'rock.00054.au',
#   'rock.00044.au',
#   'rock.00015.au',
#   'rock.00083.au',
#   'rock.00021.au',
#   'rock.00070.au',
#   'rock.00061.au',
#   'rock.00030.au',
#   'rock.00092.au',
#   'rock.00004.au',
#   'rock.00055.au',
#   'rock.00045.au',
#   'rock.00014.au',
#   'rock.00082.au',
#   'rock.00020.au',
#   'rock.00071.au',
#   'rock.00051.au',
#   'rock.00000.au',
#   'rock.00034.au',
#   'rock.00065.au',
#   'rock.00096.au',
#   'rock.00086.au',
#   'rock.00075.au',
#   'rock.00024.au',
#   'rock.00010.au',
#   'rock.00041.au',
#   'rock.00099.au',
#   'rock.00089.au',
#   'rock.00098.au',
#   'rock.00088.au'],
#  './data/genres/hiphop': ['hiphop.00017.au',
#   'hiphop.00046.au',
#   'hiphop.00072.au',
#   'hiphop.00023.au',
#   'hiphop.00081.au',
#   'hiphop.00091.au',
#   'hiphop.00033.au',
#   'hiphop.00062.au',
#   'hiphop.00056.au',
#   'hiphop.00007.au',
#   'hiphop.00027.au',
#   'hiphop.00076.au',
#   'hiphop.00085.au',
#   'hiphop.00042.au',
#   'hiphop.00013.au',
#   'hiphop.00003.au',
#   'hiphop.00052.au',
#   'hiphop.00095.au',
#   'hiphop.00066.au',
#   'hiphop.00037.au',
#   'hiphop.00026.au',
#   'hiphop.00077.au',
#   'hiphop.00084.au',
#   'hiphop.00043.au',
#   'hiphop.00012.au',
#   'hiphop.00002.au',
#   'hiphop.00053.au',
#   'hiphop.00094.au',
#   'hiphop.00067.au',
#   'hiphop.00036.au',
#   'hiphop.00016.au',
#   'hiphop.00047.au',
#   'hiphop.00073.au',
#   'hiphop.00022.au',
#   'hiphop.00080.au',
#   'hiphop.00090.au',
#   'hiphop.00032.au',
#   'hiphop.00063.au',
#   'hiphop.00057.au',
#   'hiphop.00006.au',
#   'hiphop.00078.au',
#   'hiphop.00029.au',
#   'hiphop.00039.au',
#   'hiphop.00068.au',
#   'hiphop.00048.au',
#   'hiphop.00019.au',
#   'hiphop.00009.au',
#   'hiphop.00058.au',
#   'hiphop.00049.au',
#   'hiphop.00018.au',
#   'hiphop.00008.au',
#   'hiphop.00059.au',
#   'hiphop.00079.au',
#   'hiphop.00028.au',
#   'hiphop.00038.au',
#   'hiphop.00069.au',
#   'hiphop.00089.au',
#   'hiphop.00099.au',
#   'hiphop.00088.au',
#   'hiphop.00098.au',
#   'hiphop.00087.au',
#   'hiphop.00074.au',
#   'hiphop.00025.au',
#   'hiphop.00011.au',
#   'hiphop.00040.au',
#   'hiphop.00050.au',
#   'hiphop.00001.au',
#   'hiphop.00035.au',
#   'hiphop.00064.au',
#   'hiphop.00097.au',
#   'hiphop.00044.au',
#   'hiphop.00015.au',
#   'hiphop.00083.au',
#   'hiphop.00021.au',
#   'hiphop.00070.au',
#   'hiphop.00060.au',
#   'hiphop.00031.au',
#   'hiphop.00093.au',
#   'hiphop.00005.au',
#   'hiphop.00054.au',
#   'hiphop.00045.au',
#   'hiphop.00014.au',
#   'hiphop.00082.au',
#   'hiphop.00020.au',
#   'hiphop.00071.au',
#   'hiphop.00061.au',
#   'hiphop.00030.au',
#   'hiphop.00092.au',
#   'hiphop.00004.au',
#   'hiphop.00055.au',
#   'hiphop.00086.au',
#   'hiphop.00075.au',
#   'hiphop.00024.au',
#   'hiphop.00010.au',
#   'hiphop.00041.au',
#   'hiphop.00051.au',
#   'hiphop.00000.au',
#   'hiphop.00034.au',
#   'hiphop.00065.au',
#   'hiphop.00096.au'],
#  './data/genres/country': ['country.00058.au',
#   'country.00009.au',
#   'country.00019.au',
#   'country.00048.au',
#   'country.00068.au',
#   'country.00039.au',
#   'country.00029.au',
#   'country.00078.au',
#   'country.00069.au',
#   'country.00038.au',
#   'country.00028.au',
#   'country.00079.au',
#   'country.00059.au',
#   'country.00008.au',
#   'country.00018.au',
#   'country.00049.au',
#   'country.00095.au',
#   'country.00037.au',
#   'country.00066.au',
#   'country.00052.au',
#   'country.00003.au',
#   'country.00013.au',
#   'country.00042.au',
#   'country.00076.au',
#   'country.00027.au',
#   'country.00085.au',
#   'country.00007.au',
#   'country.00056.au',
#   'country.00091.au',
#   'country.00062.au',
#   'country.00033.au',
#   'country.00023.au',
#   'country.00072.au',
#   'country.00081.au',
#   'country.00046.au',
#   'country.00017.au',
#   'country.00006.au',
#   'country.00057.au',
#   'country.00090.au',
#   'country.00063.au',
#   'country.00032.au',
#   'country.00022.au',
#   'country.00073.au',
#   'country.00080.au',
#   'country.00047.au',
#   'country.00016.au',
#   'country.00094.au',
#   'country.00036.au',
#   'country.00067.au',
#   'country.00053.au',
#   'country.00002.au',
#   'country.00012.au',
#   'country.00043.au',
#   'country.00077.au',
#   'country.00026.au',
#   'country.00084.au',
#   'country.00054.au',
#   'country.00005.au',
#   'country.00031.au',
#   'country.00060.au',
#   'country.00093.au',
#   'country.00083.au',
#   'country.00070.au',
#   'country.00021.au',
#   'country.00015.au',
#   'country.00044.au',
#   'country.00064.au',
#   'country.00035.au',
#   'country.00097.au',
#   'country.00001.au',
#   'country.00050.au',
#   'country.00040.au',
#   'country.00011.au',
#   'country.00087.au',
#   'country.00025.au',
#   'country.00074.au',
#   'country.00065.au',
#   'country.00034.au',
#   'country.00096.au',
#   'country.00000.au',
#   'country.00051.au',
#   'country.00041.au',
#   'country.00010.au',
#   'country.00086.au',
#   'country.00024.au',
#   'country.00075.au',
#   'country.00055.au',
#   'country.00004.au',
#   'country.00030.au',
#   'country.00061.au',
#   'country.00092.au',
#   'country.00082.au',
#   'country.00071.au',
#   'country.00020.au',
#   'country.00014.au',
#   'country.00045.au',
#   'country.00099.au',
#   'country.00089.au',
#   'country.00098.au',
#   'country.00088.au'],
#  './data/genres/jazz': ['jazz.00061.au',
#   'jazz.00030.au',
#   'jazz.00092.au',
#   'jazz.00004.au',
#   'jazz.00055.au',
#   'jazz.00045.au',
#   'jazz.00014.au',
#   'jazz.00082.au',
#   'jazz.00020.au',
#   'jazz.00071.au',
#   'jazz.00051.au',
#   'jazz.00000.au',
#   'jazz.00034.au',
#   'jazz.00065.au',
#   'jazz.00096.au',
#   'jazz.00086.au',
#   'jazz.00075.au',
#   'jazz.00024.au',
#   'jazz.00010.au',
#   'jazz.00041.au',
#   'jazz.00050.au',
#   'jazz.00001.au',
#   'jazz.00035.au',
#   'jazz.00064.au',
#   'jazz.00097.au',
#   'jazz.00087.au',
#   'jazz.00074.au',
#   'jazz.00025.au',
#   'jazz.00011.au',
#   'jazz.00040.au',
#   'jazz.00060.au',
#   'jazz.00031.au',
#   'jazz.00093.au',
#   'jazz.00005.au',
#   'jazz.00054.au',
#   'jazz.00044.au',
#   'jazz.00015.au',
#   'jazz.00083.au',
#   'jazz.00021.au',
#   'jazz.00070.au',
#   'jazz.00098.au',
#   'jazz.00088.au',
#   'jazz.00099.au',
#   'jazz.00089.au',
#   'jazz.00008.au',
#   'jazz.00059.au',
#   'jazz.00049.au',
#   'jazz.00018.au',
#   'jazz.00038.au',
#   'jazz.00069.au',
#   'jazz.00079.au',
#   'jazz.00028.au',
#   'jazz.00039.au',
#   'jazz.00068.au',
#   'jazz.00078.au',
#   'jazz.00029.au',
#   'jazz.00009.au',
#   'jazz.00058.au',
#   'jazz.00048.au',
#   'jazz.00019.au',
#   'jazz.00002.au',
#   'jazz.00053.au',
#   'jazz.00094.au',
#   'jazz.00067.au',
#   'jazz.00036.au',
#   'jazz.00026.au',
#   'jazz.00077.au',
#   'jazz.00084.au',
#   'jazz.00043.au',
#   'jazz.00012.au',
#   'jazz.00090.au',
#   'jazz.00032.au',
#   'jazz.00063.au',
#   'jazz.00057.au',
#   'jazz.00006.au',
#   'jazz.00016.au',
#   'jazz.00047.au',
#   'jazz.00073.au',
#   'jazz.00022.au',
#   'jazz.00080.au',
#   'jazz.00091.au',
#   'jazz.00033.au',
#   'jazz.00062.au',
#   'jazz.00056.au',
#   'jazz.00007.au',
#   'jazz.00017.au',
#   'jazz.00046.au',
#   'jazz.00072.au',
#   'jazz.00023.au',
#   'jazz.00081.au',
#   'jazz.00003.au',
#   'jazz.00052.au',
#   'jazz.00095.au',
#   'jazz.00066.au',
#   'jazz.00037.au',
#   'jazz.00027.au',
#   'jazz.00076.au',
#   'jazz.00085.au',
#   'jazz.00042.au',
#   'jazz.00013.au']}

# %%
read_wave = {}
j = 0
for folder, file in wave_files.items():
    i = 0
    for read in file:
        read_wave[m_files[0][j]+str(i)]=os.path.join(folder, read)
        i+=1
    j+=1

# %%
len(read_wave)
# Out:
# 1000

# %%
def load_wav(files):
    all_loads = {}
    for folder, file in files.items():
        y, sr = librosa.load(file, sr=22050)
        all_loads[folder]=y
    return all_loads

# %%
loading_files = load_wav(read_wave)
loading_files
# Out:
# {'pop0': array([0.31271362, 0.4494934 , 0.35662842, ..., 0.20315552, 0.23342896,
#         0.07855225], dtype=float32),
#  'pop1': array([ 0.19979858,  0.16345215,  0.16397095, ...,  0.00131226,
#         -0.01599121,  0.012146  ], dtype=float32),
#  'pop2': array([ 0.10684204,  0.13616943,  0.074646  , ..., -0.31143188,
#         -0.3444519 , -0.332489  ], dtype=float32),
#  'pop3': array([0.37789917, 0.22433472, 0.48712158, ..., 0.4614563 , 0.10275269,
#         0.47579956], dtype=float32),
#  'pop4': array([ 0.00137329, -0.00704956,  0.00338745, ...,  0.17050171,
#          0.16552734,  0.15499878], dtype=float32),
#  'pop5': array([-0.0340271 , -0.04330444, -0.0463562 , ...,  0.08895874,
#          0.06835938,  0.01708984], dtype=float32),
#  'pop6': array([-0.05557251, -0.0430603 , -0.13937378, ..., -0.26757812,
#         -0.3048706 , -0.13964844], dtype=float32),
#  'pop7': array([-0.05828857,  0.01071167,  0.09915161, ...,  0.03128052,
#         -0.01806641, -0.00238037], dtype=float32),
#  'pop8': array([ 0.01235962, -0.01074219, -0.03161621, ..., -0.19876099,
#          0.03173828,  0.05938721], dtype=float32),
#  'pop9': array([0.34866333, 0.33044434, 0.3052063 , ..., 0.07794189, 0.09710693,
#         0.02154541], dtype=float32),
#  'pop10': array([ 0.16629028,  0.19113159,  0.19692993, ..., -0.2711792 ,
#         -0.40167236, -0.372406  ], dtype=float32),
#  'pop11': array([ 0.23556519,  0.13513184,  0.04632568, ..., -0.19186401,
#         -0.29864502, -0.36026   ], dtype=float32),
#  'pop12': array([-0.51446533, -0.1772461 , -0.33996582, ...,  0.0328064 ,
#         -0.03161621,  0.0484314 ], dtype=float32),
#  'pop13': array([-0.13864136,  0.14367676, -0.15341187, ..., -0.125     ,
#         -0.15026855, -0.14309692], dtype=float32),
#  'pop14': array([-0.00411987, -0.01394653, -0.00933838, ...,  0.1670227 ,
#          0.06036377,  0.04608154], dtype=float32),
#  'pop15': array([-0.19229126, -0.08969116,  0.02322388, ..., -0.16653442,
#         -0.0585022 ,  0.01345825], dtype=float32),
#  'pop16': array([0.2953186 , 0.21789551, 0.2272644 , ..., 0.14749146, 0.30541992,
#         0.38446045], dtype=float32),
#  'pop17': array([ 0.20877075,  0.05661011,  0.1496582 , ..., -0.15530396,
#          0.04458618,  0.0536499 ], dtype=float32),
#  'pop18': array([-0.19754028, -0.19104004, -0.14093018, ..., -0.17849731,
#         -0.15228271, -0.18267822], dtype=float32),
#  'pop19': array([-0.09274292, -0.11630249, -0.11886597, ...,  0.14419556,
#          0.16311646,  0.09634399], dtype=float32),
#  'pop20': array([-0.0340271 , -0.03396606, -0.03314209, ...,  0.12954712,
#          0.21264648,  0.15942383], dtype=float32),
#  'pop21': array([-0.08126831,  0.03677368,  0.02056885, ..., -0.12475586,
#         -0.08557129, -0.05020142], dtype=float32),
#  'pop22': array([-0.42837524, -0.4496765 , -0.46420288, ..., -0.0645752 ,
#          0.08364868,  0.10876465], dtype=float32),
#  'pop23': array([0.1227417 , 0.07086182, 0.07052612, ..., 0.36099243, 0.36624146,
#         0.32626343], dtype=float32),
#  'pop24': array([ 0.03451538,  0.04815674,  0.06430054, ..., -0.06954956,
#         -0.1444397 , -0.19223022], dtype=float32),
#  'pop25': array([ 0.32260132,  0.28216553,  0.27111816, ..., -0.29141235,
#         -0.82580566, -0.31747437], dtype=float32),
#  'pop26': array([-0.0411377 , -0.03457642, -0.04684448, ...,  0.49258423,
#          0.5081787 ,  0.6766968 ], dtype=float32),
#  'pop27': array([-0.9907532 , -0.9530945 , -0.99102783, ...,  0.32305908,
#          0.42929077,  0.0949707 ], dtype=float32),
#  'pop28': array([ 0.62197876,  0.526947  ,  0.5707092 , ..., -0.01599121,
#          0.18591309,  0.37527466], dtype=float32),
#  'pop29': array([-0.0249939 , -0.01815796, -0.02023315, ..., -0.36505127,
#         -0.4237976 , -0.42385864], dtype=float32),
#  'pop30': array([-0.13348389, -0.09143066, -0.07568359, ...,  0.15698242,
#          0.18441772,  0.19113159], dtype=float32),
#  'pop31': array([-0.00378418,  0.04263306,  0.04504395, ..., -0.31472778,
#         -0.2567749 , -0.3123474 ], dtype=float32),
#  'pop32': array([0.35791016, 0.3979187 , 0.32870483, ..., 0.09716797, 0.04232788,
#         0.01092529], dtype=float32),
#  'pop33': array([ 0.15924072,  0.11972046,  0.1126709 , ..., -0.07067871,
#         -0.01205444,  0.01016235], dtype=float32),
#  'pop34': array([-0.03408813, -0.10879517,  0.02957153, ...,  0.0513916 ,
#          0.22744751,  0.1673584 ], dtype=float32),
#  'pop35': array([-0.0295105 , -0.03182983, -0.02349854, ..., -0.03009033,
#         -0.02676392, -0.00540161], dtype=float32),
#  'pop36': array([0.22735596, 0.23406982, 0.23345947, ..., 0.25195312, 0.32565308,
#         0.09817505], dtype=float32),
#  'pop37': array([-0.35333252, -0.26159668, -0.04421997, ...,  0.11123657,
#          0.03106689, -0.06323242], dtype=float32),
#  'pop38': array([-0.00198364,  0.06552124,  0.1253357 , ...,  0.22796631,
#          0.31658936,  0.3052063 ], dtype=float32),
#  'pop39': array([-0.25305176, -0.41104126, -0.35287476, ..., -0.17889404,
#         -0.12127686, -0.05593872], dtype=float32),
#  'pop40': array([-0.24386597, -0.22479248, -0.18130493, ..., -0.09216309,
#         -0.10147095, -0.18832397], dtype=float32),
#  'pop41': array([-0.04464722, -0.05615234, -0.04205322, ...,  0.02310181,
#          0.02587891,  0.0269165 ], dtype=float32),
#  'pop42': array([-0.02728271, -0.03622437, -0.04992676, ...,  0.04800415,
#          0.03561401,  0.03475952], dtype=float32),
#  'pop43': array([-0.26919556, -0.24667358, -0.18579102, ...,  0.01272583,
#         -0.00299072, -0.0149231 ], dtype=float32),
#  'pop44': array([0.19973755, 0.19616699, 0.2041626 , ..., 0.074646  , 0.08425903,
#         0.17904663], dtype=float32),
#  'pop45': array([-0.00158691, -0.00152588, -0.0118103 , ...,  0.00793457,
#          0.05090332,  0.01623535], dtype=float32),
#  'pop46': array([-0.1217041 , -0.11859131, -0.12683105, ..., -0.37356567,
#         -0.4385376 , -0.3409729 ], dtype=float32),
#  'pop47': array([ 0.4713745 ,  0.42648315,  0.41140747, ...,  0.03622437,
#         -0.07781982, -0.12097168], dtype=float32),
#  'pop48': array([-0.2119751 , -0.0675354 , -0.18411255, ..., -0.50982666,
#         -0.85583496, -0.37353516], dtype=float32),
#  'pop49': array([-0.09463501, -0.11407471, -0.13574219, ...,  0.2437439 ,
#          0.07592773,  0.18096924], dtype=float32),
#  'pop50': array([ 0.10803223, -0.0798645 , -0.06811523, ...,  0.16378784,
#          0.1510315 ,  0.13223267], dtype=float32),
#  'pop51': array([-0.05612183, -0.02548218,  0.00076294, ..., -0.27697754,
#         -0.26974487, -0.34283447], dtype=float32),
#  'pop52': array([ 0.06802368,  0.11877441,  0.07830811, ..., -0.18048096,
#         -0.14428711, -0.22964478], dtype=float32),
#  'pop53': array([ 0.04043579, -0.11618042,  0.04278564, ...,  0.655365  ,
#          0.592041  ,  0.6399536 ], dtype=float32),
#  'pop54': array([ 0.02838135, -0.05447388,  0.10992432, ..., -0.07067871,
#         -0.13583374, -0.16445923], dtype=float32),
#  'pop55': array([-0.18103027, -0.14593506, -0.11779785, ...,  0.31704712,
#          0.13739014, -0.08468628], dtype=float32),
#  'pop56': array([ 0.04147339,  0.03170776,  0.01766968, ..., -0.00732422,
#         -0.01150513, -0.01361084], dtype=float32),
#  'pop57': array([ 0.10720825,  0.16122437,  0.28585815, ..., -0.22924805,
#         -0.20629883, -0.11334229], dtype=float32),
#  'pop58': array([-0.01693726, -0.01861572,  0.00778198, ...,  0.05941772,
#          0.07400513,  0.07827759], dtype=float32),
#  'pop59': array([-0.09075928, -0.08178711, -0.06820679, ...,  0.05010986,
#          0.0112915 , -0.00152588], dtype=float32),
#  'pop60': array([0.06167603, 0.06103516, 0.06005859, ..., 0.05038452, 0.06747437,
#         0.05651855], dtype=float32),
#  'pop61': array([-0.06268311, -0.07568359, -0.08706665, ...,  0.02651978,
#          0.00140381, -0.01583862], dtype=float32),
#  'pop62': array([0.03201294, 0.0428772 , 0.04910278, ..., 0.04016113, 0.05880737,
#         0.06878662], dtype=float32),
#  'pop63': array([-0.10604858, -0.08395386, -0.09460449, ..., -0.44470215,
#         -0.27789307, -0.4321289 ], dtype=float32),
#  'pop64': array([-0.02709961, -0.02371216,  0.05221558, ..., -0.15200806,
#         -0.16900635, -0.25219727], dtype=float32),
#  'pop65': array([0.2557068 , 0.2401123 , 0.27786255, ..., 0.5334778 , 0.6204529 ,
#         0.45776367], dtype=float32),
#  'pop66': array([-0.02783203,  0.03942871,  0.01895142, ..., -0.11349487,
#         -0.13946533, -0.16949463], dtype=float32),
#  'pop67': array([-0.401886  , -0.44421387, -0.40725708, ..., -0.3289795 ,
#         -0.39907837, -0.5903015 ], dtype=float32),
#  'pop68': array([-0.0887146 , -0.09524536, -0.10275269, ...,  0.04016113,
#          0.03860474,  0.02639771], dtype=float32),
#  'pop69': array([-0.07617188, -0.05743408, -0.02032471, ...,  0.3598938 ,
#         -0.03610229,  0.21017456], dtype=float32),
#  'pop70': array([0.2953186 , 0.21789551, 0.2272644 , ..., 0.14749146, 0.30541992,
#         0.38446045], dtype=float32),
#  'pop71': array([-0.1812439 , -0.11434937, -0.12710571, ..., -0.10079956,
#         -0.07598877, -0.06747437], dtype=float32),
#  'pop72': array([-0.04116821, -0.0506897 , -0.07846069, ...,  0.17160034,
#          0.13851929,  0.05413818], dtype=float32),
#  'pop73': array([ 0.07824707,  0.07504272,  0.07333374, ..., -0.00839233,
#         -0.00042725,  0.01071167], dtype=float32),
#  'pop74': array([ 0.0050354 ,  0.00750732,  0.00408936, ..., -0.05233765,
#          0.02938843, -0.14187622], dtype=float32),
#  'pop75': array([ 0.00384521,  0.02346802,  0.07144165, ...,  0.04241943,
#         -0.10992432, -0.07177734], dtype=float32),
#  'pop76': array([-0.12844849, -0.10952759, -0.06726074, ..., -0.31854248,
#         -0.31814575, -0.43252563], dtype=float32),
#  'pop77': array([ 0.16674805,  0.14935303,  0.13183594, ..., -0.04043579,
#         -0.02600098, -0.01837158], dtype=float32),
#  'pop78': array([-0.11010742, -0.15396118,  0.02597046, ..., -0.20388794,
#         -0.24765015, -0.2553711 ], dtype=float32),
#  'pop79': array([-0.01672363,  0.00247192, -0.0020752 , ..., -0.13113403,
#         -0.02645874,  0.07791138], dtype=float32),
#  'pop80': array([ 0.03933716,  0.04083252,  0.04171753, ..., -0.03192139,
#         -0.04574585, -0.03948975], dtype=float32),
#  'pop81': array([ 0.05722046,  0.06097412,  0.06286621, ..., -0.37835693,
#         -0.41036987, -0.5925293 ], dtype=float32),
#  'pop82': array([ 0.08834839,  0.08383179,  0.05740356, ..., -0.18606567,
#         -0.1984253 , -0.16970825], dtype=float32),
#  'pop83': array([ 0.01809692, -0.00827026,  0.02719116, ..., -0.11218262,
#         -0.03579712, -0.00421143], dtype=float32),
#  'pop84': array([ 0.10751343,  0.11776733,  0.11846924, ..., -0.0592041 ,
#         -0.22479248, -0.05606079], dtype=float32),
#  'pop85': array([-0.04229736, -0.05657959, -0.12426758, ...,  0.046875  ,
#          0.05056763,  0.02993774], dtype=float32),
#  'pop86': array([0.04498291, 0.04544067, 0.0451355 , ..., 0.3659973 , 0.41201782,
#         0.4533081 ], dtype=float32),
#  'pop87': array([ 0.0725708 , -0.00869751, -0.01080322, ..., -0.06570435,
#          0.03738403, -0.07449341], dtype=float32),
#  'pop88': array([ 0.07803345, -0.03765869,  0.12664795, ...,  0.45474243,
#          0.43637085,  0.35180664], dtype=float32),
#  'pop89': array([-0.04229736, -0.05657959, -0.12426758, ...,  0.046875  ,
#          0.05056763,  0.02993774], dtype=float32),
#  'pop90': array([ 0.00708008, -0.00595093, -0.00735474, ...,  0.23013306,
#          0.27703857,  0.28320312], dtype=float32),
#  'pop91': array([ 0.02270508,  0.05072021,  0.06884766, ..., -0.06430054,
#         -0.0652771 , -0.06048584], dtype=float32),
#  'pop92': array([-0.02984619, -0.05477905, -0.06448364, ..., -0.2107544 ,
#         -0.21142578, -0.22033691], dtype=float32),
#  'pop93': array([ 2.5878906e-02, -1.2207031e-04,  3.6834717e-02, ...,
#          3.9044189e-01,  2.3257446e-01,  2.8952026e-01], dtype=float32),
#  'pop94': array([ 0.09573364,  0.10336304,  0.03237915, ..., -0.03540039,
#         -0.15487671, -0.11849976], dtype=float32),
#  'pop95': array([0.04934692, 0.0451355 , 0.02978516, ..., 0.29040527, 0.2875061 ,
#         0.24035645], dtype=float32),
#  'pop96': array([-0.42181396, -0.4069214 , -0.34994507, ..., -0.2857666 ,
#         -0.19955444, -0.08422852], dtype=float32),
#  'pop97': array([0.14556885, 0.09173584, 0.03552246, ..., 0.00228882, 0.03567505,
#         0.08633423], dtype=float32),
#  'pop98': array([0.7692261 , 0.2246399 , 0.69036865, ..., 0.21218872, 0.21685791,
#         0.24371338], dtype=float32),
#  'pop99': array([0.03704834, 0.03735352, 0.037323  , ..., 0.05224609, 0.05944824,
#         0.12362671], dtype=float32),
#  'metal0': array([ 0.03286743,  0.03845215,  0.06991577, ..., -0.4360962 ,
#         -0.40264893, -0.37072754], dtype=float32),
#  'metal1': array([-0.22640991, -0.38705444, -0.40716553, ..., -0.16696167,
#         -0.14016724, -0.09039307], dtype=float32),
#  'metal2': array([-0.0241394 ,  0.05383301,  0.08557129, ...,  0.15316772,
#          0.18502808,  0.21829224], dtype=float32),
#  'metal3': array([-0.06201172, -0.0647583 ,  0.01269531, ...,  0.17086792,
#          0.18267822,  0.17208862], dtype=float32),
#  'metal4': array([ 0.14898682,  0.02368164, -0.16418457, ..., -0.03533936,
#         -0.03482056, -0.03063965], dtype=float32),
#  'metal5': array([-0.01809692,  0.00430298,  0.01394653, ..., -0.17477417,
#         -0.28582764, -0.34246826], dtype=float32),
#  'metal6': array([-0.00775146, -0.02368164, -0.03305054, ...,  0.00143433,
#         -0.01153564,  0.00460815], dtype=float32),
#  'metal7': array([-0.07626343, -0.00305176,  0.00396729, ..., -0.13336182,
#         -0.05142212, -0.07611084], dtype=float32),
#  'metal8': array([-0.13476562, -0.03012085, -0.05203247, ..., -0.27575684,
#         -0.29690552, -0.29125977], dtype=float32),
#  'metal9': array([-0.1156311 , -0.04870605, -0.02822876, ..., -0.01867676,
#         -0.02383423, -0.00875854], dtype=float32),
#  'metal10': array([ 0.41107178,  0.43389893,  0.36236572, ..., -0.30221558,
#         -0.23269653, -0.29507446], dtype=float32),
#  'metal11': array([-0.08648682, -0.10812378, -0.05697632, ...,  0.00598145,
#         -0.00784302, -0.01211548], dtype=float32),
#  'metal12': array([-0.08584595, -0.09381104, -0.21917725, ...,  0.16452026,
#          0.12005615,  0.1569519 ], dtype=float32),
#  'metal13': array([-0.24032593, -0.2849121 , -0.30215454, ..., -0.06997681,
#         -0.01342773, -0.05044556], dtype=float32),
#  'metal14': array([-0.11505127, -0.12127686, -0.13723755, ..., -0.20852661,
#         -0.13613892, -0.03717041], dtype=float32),
#  'metal15': array([-0.00717163, -0.00680542,  0.00445557, ...,  0.00814819,
#         -0.02844238, -0.02645874], dtype=float32),
#  'metal16': array([ 0.5633545 ,  0.65719604,  0.42919922, ..., -0.04171753,
#          0.0887146 , -0.3196106 ], dtype=float32),
#  'metal17': array([ 0.13366699,  0.20907593,  0.18832397, ..., -0.14013672,
#         -0.11312866, -0.04711914], dtype=float32),
#  'metal18': array([-0.05050659,  0.26184082,  0.3322754 , ...,  0.14788818,
#          0.21975708,  0.08520508], dtype=float32),
#  'metal19': array([0.1164856 , 0.1194458 , 0.12341309, ..., 0.01867676, 0.06533813,
#         0.034729  ], dtype=float32),
#  'metal20': array([0.22305298, 0.35424805, 0.42669678, ..., 0.12341309, 0.17764282,
#         0.23867798], dtype=float32),
#  'metal21': array([ 0.04193115,  0.06799316,  0.05114746, ...,  0.23345947,
#          0.12826538, -0.0302124 ], dtype=float32),
#  'metal22': array([-0.08648682, -0.16723633, -0.12652588, ...,  0.10470581,
#          0.13891602,  0.16149902], dtype=float32),
#  'metal23': array([-0.01220703,  0.02713013,  0.15164185, ..., -0.13601685,
#         -0.09924316, -0.22912598], dtype=float32),
#  'metal24': array([ 0.16769409,  0.15982056,  0.14202881, ..., -0.2296753 ,
#         -0.04956055,  0.07061768], dtype=float32),
#  'metal25': array([-0.03878784,  0.05355835,  0.00912476, ...,  0.09588623,
#          0.08117676,  0.05422974], dtype=float32),
#  'metal26': array([0.03948975, 0.05557251, 0.03442383, ..., 0.09945679, 0.01248169,
#         0.03640747], dtype=float32),
#  'metal27': array([-0.03417969, -0.02215576,  0.01190186, ...,  0.15057373,
#          0.08218384,  0.01947021], dtype=float32),
#  'metal28': array([-0.18701172, -0.11355591, -0.06124878, ...,  0.01394653,
#          0.0904541 ,  0.11785889], dtype=float32),
#  'metal29': array([-0.12237549, -0.04919434,  0.04440308, ..., -0.17837524,
#         -0.08401489, -0.0284729 ], dtype=float32),
#  'metal30': array([ 0.34439087,  0.42144775,  0.19821167, ..., -0.31454468,
#         -0.17037964, -0.17459106], dtype=float32),
#  'metal31': array([ 0.10452271,  0.15914917,  0.10348511, ..., -0.01296997,
#          0.00421143,  0.00302124], dtype=float32),
#  'metal32': array([-0.01809692,  0.00430298,  0.01394653, ..., -0.17477417,
#         -0.28582764, -0.34246826], dtype=float32),
#  'metal33': array([-0.0173645 ,  0.01452637,  0.02264404, ..., -0.03912354,
#         -0.03588867, -0.01013184], dtype=float32),
#  'metal34': array([ 0.1300354 ,  0.15908813,  0.09783936, ..., -0.18374634,
#         -0.22894287, -0.19534302], dtype=float32),
#  'metal35': array([ 0.04074097,  0.04595947,  0.03143311, ...,  0.0904541 ,
#         -0.03186035, -0.05340576], dtype=float32),
#  'metal36': array([ 0.01483154,  0.00656128, -0.00634766, ..., -0.00927734,
#         -0.02938843,  0.00762939], dtype=float32),
#  'metal37': array([ 0.01049805, -0.09039307, -0.08886719, ..., -0.19641113,
#         -0.03323364,  0.06637573], dtype=float32),
#  'metal38': array([ 0.03741455, -0.0725708 , -0.11480713, ..., -0.16549683,
#         -0.11206055, -0.11181641], dtype=float32),
#  'metal39': array([ 0.03787231,  0.04629517,  0.06582642, ..., -0.0123291 ,
#         -0.01153564, -0.0925293 ], dtype=float32),
#  'metal40': array([-0.3647461 , -0.39352417, -0.40853882, ..., -0.1711731 ,
#         -0.17068481, -0.15899658], dtype=float32),
#  'metal41': array([ 0.13366699,  0.20907593,  0.18832397, ..., -0.14013672,
#         -0.11312866, -0.04711914], dtype=float32),
#  'metal42': array([-0.11386108, -0.15759277, -0.08456421, ..., -0.4359436 ,
#         -0.4033203 , -0.1847229 ], dtype=float32),
#  'metal43': array([-0.04174805, -0.06900024, -0.04388428, ...,  0.03582764,
#          0.03430176, -0.00180054], dtype=float32),
#  'metal44': array([-0.29574585, -0.26992798, -0.15057373, ...,  0.08013916,
#         -0.02252197, -0.15100098], dtype=float32),
#  'metal45': array([-0.02087402, -0.02761841, -0.04104614, ..., -0.02133179,
#          0.05526733,  0.04312134], dtype=float32),
#  'metal46': array([-0.00836182,  0.00436401, -0.01062012, ...,  0.0295105 ,
#          0.03063965,  0.06661987], dtype=float32),
#  'metal47': array([-0.05740356,  0.00628662,  0.06463623, ...,  0.06286621,
#          0.02740479, -0.04785156], dtype=float32),
#  'metal48': array([ 0.0222168 ,  0.0296936 ,  0.03231812, ...,  0.04040527,
#         -0.0479126 , -0.12384033], dtype=float32),
#  'metal49': array([ 0.39987183,  0.567688  ,  0.3338318 , ..., -0.09738159,
#          0.05456543,  0.04785156], dtype=float32),
#  'metal50': array([ 0.0395813 ,  0.02209473, -0.01251221, ..., -0.06118774,
#         -0.04156494,  0.06515503], dtype=float32),
#  'metal51': array([-0.1151123 , -0.13549805, -0.14663696, ..., -0.12606812,
#         -0.06646729, -0.00292969], dtype=float32),
#  'metal52': array([ 0.04074097,  0.04595947,  0.03143311, ...,  0.0904541 ,
#         -0.03186035, -0.05340576], dtype=float32),
#  'metal53': array([-0.12442017, -0.20019531, -0.14730835, ...,  0.01928711,
#          0.00610352, -0.00448608], dtype=float32),
#  'metal54': array([-0.04641724, -0.00845337,  0.04092407, ...,  0.48138428,
#          0.4666443 ,  0.37408447], dtype=float32),
#  'metal55': array([ 0.05142212,  0.07095337,  0.0239563 , ...,  0.00317383,
#         -0.03045654,  0.02932739], dtype=float32),
#  'metal56': array([ 0.05136108,  0.03598022,  0.00067139, ..., -0.15332031,
#         -0.09997559, -0.14892578], dtype=float32),
#  'metal57': array([0.1539917 , 0.19332886, 0.20690918, ..., 0.1413269 , 0.12460327,
#         0.1302185 ], dtype=float32),
#  'metal58': array([-0.14147949, -0.05548096,  0.10794067, ...,  0.01657104,
#          0.17730713,  0.14160156], dtype=float32),
#  'metal59': array([-0.03417969, -0.02215576,  0.01190186, ...,  0.15057373,
#          0.08218384,  0.01947021], dtype=float32),
#  'metal60': array([-0.236969  , -0.26339722, -0.25302124, ..., -0.29763794,
#         -0.00372314,  0.16821289], dtype=float32),
#  'metal61': array([-0.08712769, -0.12106323, -0.14590454, ...,  0.04421997,
#          0.0440979 ,  0.04092407], dtype=float32),
#  'metal62': array([ 0.03479004,  0.08447266,  0.0668335 , ..., -0.10333252,
#         -0.12298584, -0.15881348], dtype=float32),
#  'metal63': array([ 0.05352783,  0.15640259,  0.14309692, ..., -0.29437256,
#         -0.26190186, -0.21813965], dtype=float32),
#  'metal64': array([-0.0038147 ,  0.08908081,  0.16000366, ..., -0.00866699,
#         -0.01025391,  0.00592041], dtype=float32),
#  'metal65': array([ 0.00723267, -0.09487915,  0.        , ...,  0.19946289,
#          0.06079102, -0.01303101], dtype=float32),
#  'metal66': array([-0.24209595, -0.04730225,  0.06091309, ..., -0.1425476 ,
#         -0.17355347, -0.12905884], dtype=float32),
#  'metal67': array([-0.03897095, -0.06414795, -0.09539795, ..., -0.05166626,
#         -0.0802002 , -0.05831909], dtype=float32),
#  'metal68': array([ 0.11010742,  0.11685181,  0.11102295, ..., -0.21173096,
#          0.04977417,  0.17297363], dtype=float32),
#  'metal69': array([ 0.0222168 ,  0.0296936 ,  0.03231812, ...,  0.04040527,
#         -0.0479126 , -0.12384033], dtype=float32),
#  'metal70': array([-0.07992554, -0.08685303, -0.05004883, ..., -0.07504272,
#         -0.12322998, -0.10430908], dtype=float32),
#  'metal71': array([ 0.03170776,  0.01437378, -0.00125122, ...,  0.06469727,
#          0.06817627,  0.08590698], dtype=float32),
#  'metal72': array([ 0.00180054,  0.02932739,  0.00665283, ..., -0.12728882,
#         -0.08517456, -0.08630371], dtype=float32),
#  'metal73': array([ 0.04806519,  0.11572266,  0.17010498, ..., -0.0383606 ,
#         -0.08569336, -0.0737915 ], dtype=float32),
#  'metal74': array([0.15292358, 0.17767334, 0.21743774, ..., 0.0614624 , 0.0770874 ,
#         0.07592773], dtype=float32),
#  'metal75': array([0.0100708 , 0.06564331, 0.06677246, ..., 0.01190186, 0.02789307,
#         0.04650879], dtype=float32),
#  'metal76': array([ 0.07336426,  0.09289551,  0.03027344, ..., -0.05554199,
#         -0.00241089,  0.05871582], dtype=float32),
#  'metal77': array([ 0.18252563,  0.04763794,  0.05682373, ..., -0.07180786,
#          0.0012207 , -0.0020752 ], dtype=float32),
#  'metal78': array([-0.08648682, -0.16723633, -0.12652588, ...,  0.10470581,
#          0.13891602,  0.16149902], dtype=float32),
#  'metal79': array([-0.48910522, -0.77838135, -0.70703125, ..., -0.09866333,
#         -0.21850586, -0.21209717], dtype=float32),
#  'metal80': array([-0.0234375 , -0.1100769 , -0.11660767, ...,  0.10198975,
#          0.06524658,  0.084198  ], dtype=float32),
#  'metal81': array([ 0.034729  ,  0.07818604,  0.0899353 , ..., -0.17190552,
#         -0.19494629, -0.19726562], dtype=float32),
#  'metal82': array([-0.12936401, -0.14221191, -0.11578369, ..., -0.07162476,
#          0.02050781,  0.02780151], dtype=float32),
#  'metal83': array([-0.0173645 ,  0.01452637,  0.02264404, ..., -0.03912354,
#         -0.03588867, -0.01013184], dtype=float32),
#  'metal84': array([ 0.06192017,  0.01989746, -0.03140259, ...,  0.11914062,
#          0.13412476,  0.10879517], dtype=float32),
#  'metal85': array([-0.29144287, -0.59036255, -0.6340332 , ..., -0.3718567 ,
#         -0.4647522 , -0.40859985], dtype=float32),
#  'metal86': array([0.22888184, 0.25204468, 0.09558105, ..., 0.19613647, 0.35977173,
#         0.2919922 ], dtype=float32),
#  'metal87': array([ 0.07171631,  0.03762817,  0.01773071, ..., -0.31219482,
#         -0.26968384, -0.1194458 ], dtype=float32),
#  'metal88': array([-0.00762939,  0.00402832,  0.01251221, ..., -0.13613892,
#         -0.07125854, -0.01226807], dtype=float32),
#  'metal89': array([-0.05136108, -0.1427002 , -0.16308594, ..., -0.29525757,
#         -0.22854614,  0.04794312], dtype=float32),
#  'metal90': array([ 0.03042603,  0.05450439,  0.14379883, ..., -0.04827881,
#         -0.01419067, -0.01443481], dtype=float32),
#  'metal91': array([-0.04263306, -0.01522827, -0.02587891, ..., -0.10150146,
#         -0.10940552, -0.11834717], dtype=float32),
#  'metal92': array([ 0.02609253,  0.06872559,  0.09588623, ..., -0.1947937 ,
#         -0.31329346, -0.28796387], dtype=float32),
#  'metal93': array([-0.00842285, -0.05541992, -0.05349731, ..., -0.19763184,
#         -0.30459595, -0.20803833], dtype=float32),
#  'metal94': array([0.19439697, 0.16574097, 0.10437012, ..., 0.12704468, 0.11346436,
#         0.09072876], dtype=float32),
#  'metal95': array([-0.09664917, -0.05780029,  0.01654053, ..., -0.4532776 ,
#         -0.45162964, -0.3480835 ], dtype=float32),
#  'metal96': array([-0.19119263, -0.23266602, -0.13912964, ..., -0.15789795,
#         -0.05615234, -0.0383606 ], dtype=float32),
#  'metal97': array([ 0.00521851, -0.03253174, -0.15594482, ..., -0.15679932,
#         -0.21084595, -0.23257446], dtype=float32),
#  'metal98': array([-0.02770996, -0.08151245, -0.09231567, ...,  0.10531616,
#          0.11734009,  0.11154175], dtype=float32),
#  'metal99': array([-0.0291748 , -0.02426147, -0.03848267, ...,  0.11984253,
#          0.06219482,  0.04144287], dtype=float32),
#  'disco0': array([ 0.10980225,  0.09988403,  0.00543213, ..., -0.00897217,
#          0.01419067, -0.10076904], dtype=float32),
#  'disco1': array([ 0.00817871,  0.00778198,  0.0067749 , ..., -0.06130981,
#         -0.05337524, -0.04385376], dtype=float32),
#  'disco2': array([ 0.0435791 ,  0.04830933,  0.0553894 , ..., -0.05081177,
#         -0.04443359, -0.03286743], dtype=float32),
#  'disco3': array([-0.04180908, -0.03515625, -0.03540039, ...,  0.01617432,
#          0.03219604,  0.05780029], dtype=float32),
#  'disco4': array([-0.08145142, -0.06890869, -0.02340698, ...,  0.25567627,
#          0.20291138,  0.11502075], dtype=float32),
#  'disco5': array([-0.13729858, -0.1456604 , -0.04525757, ...,  0.0697937 ,
#         -0.03546143,  0.10876465], dtype=float32),
#  'disco6': array([-0.01919556, -0.08374023, -0.13635254, ..., -0.17327881,
#         -0.10821533, -0.13143921], dtype=float32),
#  'disco7': array([ 0.07189941,  0.0133667 , -0.0065918 , ..., -0.05377197,
#         -0.08712769, -0.07946777], dtype=float32),
#  'disco8': array([ 0.401886  ,  0.31951904,  0.34765625, ...,  0.0692749 ,
#         -0.26049805, -0.27804565], dtype=float32),
#  'disco9': array([ 0.23718262,  0.10021973, -0.30282593, ...,  0.08404541,
#          0.11141968,  0.09255981], dtype=float32),
#  'disco10': array([-0.05325317, -0.07962036, -0.06735229, ...,  0.07620239,
#          0.0760498 ,  0.09066772], dtype=float32),
#  'disco11': array([0.02011108, 0.02133179, 0.0241394 , ..., 0.32821655, 0.18182373,
#         0.07104492], dtype=float32),
#  'disco12': array([-0.01568604,  0.01831055, -0.04498291, ..., -0.11920166,
#         -0.05703735,  0.01599121], dtype=float32),
#  'disco13': array([-0.02532959, -0.01724243, -0.01724243, ..., -0.03591919,
#         -0.04110718, -0.03720093], dtype=float32),
#  'disco14': array([-0.00808716, -0.04266357, -0.02032471, ..., -0.03939819,
#         -0.0395813 , -0.03741455], dtype=float32),
#  'disco15': array([0.21795654, 0.19354248, 0.17358398, ..., 0.10876465, 0.1008606 ,
#         0.08755493], dtype=float32),
#  'disco16': array([ 0.05078125,  0.05444336,  0.08117676, ..., -0.00238037,
#          0.        , -0.0848999 ], dtype=float32),
#  'disco17': array([0.13760376, 0.26376343, 0.36972046, ..., 0.02590942, 0.0953064 ,
#         0.13406372], dtype=float32),
#  'disco18': array([0.04678345, 0.07421875, 0.07055664, ..., 0.19915771, 0.21505737,
#         0.2149353 ], dtype=float32),
#  'disco19': array([ 0.0479126 ,  0.05447388,  0.17874146, ...,  0.04919434,
#          0.0484314 , -0.00674438], dtype=float32),
#  'disco20': array([-0.05200195, -0.05023193, -0.04733276, ...,  0.07980347,
#          0.04394531,  0.04943848], dtype=float32),
#  'disco21': array([-0.15805054, -0.14486694, -0.06796265, ..., -0.1689148 ,
#         -0.1357727 , -0.07852173], dtype=float32),
#  'disco22': array([-0.04418945, -0.03817749, -0.0229187 , ..., -0.08786011,
#         -0.08590698, -0.08248901], dtype=float32),
#  'disco23': array([-0.06140137, -0.03152466, -0.00521851, ...,  0.01834106,
#          0.00869751,  0.00863647], dtype=float32),
#  'disco24': array([-0.05606079,  0.01226807,  0.06271362, ..., -0.16149902,
#         -0.16049194, -0.16586304], dtype=float32),
#  'disco25': array([-0.4039917 , -0.78549194, -0.39001465, ..., -0.45870972,
#         -0.4875183 , -0.47406006], dtype=float32),
#  'disco26': array([ 0.11776733,  0.04101562,  0.0401001 , ..., -0.17614746,
#         -0.16220093, -0.222229  ], dtype=float32),
#  'disco27': array([ 0.12133789,  0.01956177,  0.0484314 , ...,  0.01849365,
#          0.00595093, -0.0322876 ], dtype=float32),
#  'disco28': array([-0.03701782, -0.06021118, -0.05078125, ...,  0.01199341,
#         -0.012146  ,  0.00640869], dtype=float32),
#  'disco29': array([0.04318237, 0.04827881, 0.05279541, ..., 0.20962524, 0.18035889,
#         0.13616943], dtype=float32),
#  'disco30': array([-0.15853882, -0.15530396, -0.15908813, ...,  0.02688599,
#          0.03921509,  0.03308105], dtype=float32),
#  'disco31': array([-0.01626587,  0.07577515,  0.07928467, ...,  0.2401123 ,
#          0.06555176,  0.11740112], dtype=float32),
#  'disco32': array([-0.03292847,  0.30993652,  0.48135376, ..., -0.18603516,
#         -0.01733398,  0.07772827], dtype=float32),
#  'disco33': array([ 0.07159424,  0.07232666,  0.07189941, ..., -0.1463623 ,
#         -0.09390259, -0.08886719], dtype=float32),
#  'disco34': array([-0.1459961 , -0.09658813, -0.11193848, ...,  0.02349854,
#          0.06124878,  0.06143188], dtype=float32),
#  'disco35': array([-0.336792  , -0.18792725, -0.21746826, ..., -0.1513977 ,
#         -0.13018799, -0.11328125], dtype=float32),
#  'disco36': array([0.11471558, 0.31384277, 0.43185425, ..., 0.00418091, 0.00289917,
#         0.00631714], dtype=float32),
#  'disco37': array([0.06143188, 0.06384277, 0.06430054, ..., 0.5055237 , 0.58706665,
#         0.51586914], dtype=float32),
#  'disco38': array([ 0.03369141,  0.02362061, -0.01922607, ...,  0.027771  ,
#          0.04779053,  0.04721069], dtype=float32),
#  'disco39': array([ 0.02081299,  0.08752441,  0.06787109, ..., -0.07040405,
#         -0.13134766, -0.24331665], dtype=float32),
#  'disco40': array([-0.02359009,  0.03094482, -0.00143433, ..., -0.3293457 ,
#         -0.4136963 , -0.12341309], dtype=float32),
#  'disco41': array([ 0.2637024 ,  0.24804688,  0.13317871, ..., -0.04742432,
#          0.09240723,  0.2604065 ], dtype=float32),
#  'disco42': array([-0.10388184,  0.0223999 ,  0.07470703, ..., -0.04125977,
#         -0.01043701,  0.02560425], dtype=float32),
#  'disco43': array([ 0.12200928,  0.09695435,  0.10119629, ..., -0.04769897,
#         -0.04824829, -0.04171753], dtype=float32),
#  'disco44': array([ 0.01791382,  0.00491333, -0.02185059, ..., -0.04003906,
#         -0.04852295, -0.04107666], dtype=float32),
#  'disco45': array([0.09420776, 0.09906006, 0.0581665 , ..., 0.05667114, 0.04855347,
#         0.10333252], dtype=float32),
#  'disco46': array([ 0.03356934,  0.03414917,  0.02133179, ..., -0.08337402,
#         -0.06295776, -0.04690552], dtype=float32),
#  'disco47': array([-1.04034424e-01, -1.71936035e-01, -1.84295654e-01, ...,
#          1.00402832e-02, -1.52587891e-04, -1.04003906e-01], dtype=float32),
#  'disco48': array([-0.09927368, -0.12609863, -0.11959839, ...,  0.09136963,
#          0.07055664,  0.04977417], dtype=float32),
#  'disco49': array([0.00088501, 0.01287842, 0.01678467, ..., 0.08322144, 0.09259033,
#         0.06878662], dtype=float32),
#  'disco50': array([0.06985474, 0.09182739, 0.1703186 , ..., 0.07458496, 0.13018799,
#         0.05255127], dtype=float32),
#  'disco51': array([-0.19967651, -0.10507202, -0.08612061, ..., -0.10510254,
#         -0.27670288, -0.21386719], dtype=float32),
#  'disco52': array([ 0.00375366,  0.00482178, -0.02020264, ...,  0.07357788,
#          0.05322266,  0.0329895 ], dtype=float32),
#  'disco53': array([-0.08755493, -0.14620972, -0.16326904, ...,  0.4052124 ,
#          0.58755493,  0.28518677], dtype=float32),
#  'disco54': array([-0.01702881, -0.00918579, -0.00271606, ..., -0.01229858,
#         -0.00866699, -0.00552368], dtype=float32),
#  'disco55': array([ 0.03781128,  0.06408691,  0.03387451, ..., -0.29934692,
#         -0.26086426, -0.15597534], dtype=float32),
#  'disco56': array([-0.18920898, -0.24240112, -0.1685791 , ...,  0.17984009,
#          0.13867188,  0.05758667], dtype=float32),
#  'disco57': array([-0.37817383, -0.3057251 , -0.1446228 , ..., -0.34143066,
#         -0.45291138, -0.3999939 ], dtype=float32),
#  'disco58': array([0.03063965, 0.02542114, 0.02191162, ..., 0.00616455, 0.00479126,
#         0.03515625], dtype=float32),
#  'disco59': array([ 0.01690674,  0.01544189,  0.01333618, ..., -0.13110352,
#         -0.07781982,  0.00979614], dtype=float32),
#  'disco60': array([ 0.16619873,  0.12957764,  0.10116577, ..., -0.11779785,
#         -0.13143921, -0.08724976], dtype=float32),
#  'disco61': array([ 0.43981934,  0.42642212,  0.39328003, ...,  0.16751099,
#          0.02386475, -0.08129883], dtype=float32),
#  'disco62': array([ 0.03314209,  0.00604248,  0.03399658, ...,  0.04415894,
#         -0.00759888, -0.03445435], dtype=float32),
#  'disco63': array([-0.08514404, -0.08752441, -0.09707642, ...,  0.62249756,
#          0.63378906,  0.7043152 ], dtype=float32),
#  'disco64': array([-0.18777466, -0.23693848, -0.15542603, ...,  0.03741455,
#          0.10574341,  0.09619141], dtype=float32),
#  'disco65': array([ 0.1925354 ,  0.03353882, -0.02471924, ..., -0.14624023,
#         -0.12200928, -0.07476807], dtype=float32),
#  'disco66': array([-0.06051636, -0.06201172, -0.03417969, ..., -0.01367188,
#         -0.06228638, -0.06088257], dtype=float32),
#  'disco67': array([-0.04623413, -0.01837158,  0.01364136, ..., -0.19699097,
#         -0.30047607, -0.2315979 ], dtype=float32),
#  'disco68': array([ 0.00488281,  0.00802612,  0.01834106, ..., -0.0269165 ,
#         -0.02349854, -0.01708984], dtype=float32),
#  'disco69': array([ 0.31549072,  0.35754395,  0.39300537, ..., -0.05810547,
#          0.03363037, -0.08139038], dtype=float32),
#  'disco70': array([-0.26220703, -0.1716919 , -0.01559448, ...,  0.11639404,
#          0.09091187,  0.06845093], dtype=float32),
#  'disco71': array([-0.08001709, -0.07550049, -0.08358765, ...,  0.08270264,
#          0.10083008,  0.10562134], dtype=float32),
#  'disco72': array([ 0.32540894,  0.35195923,  0.26452637, ..., -0.19857788,
#         -0.20074463, -0.15875244], dtype=float32),
#  'disco73': array([-0.00735474, -0.09512329, -0.16320801, ...,  0.10736084,
#          0.19329834,  0.24414062], dtype=float32),
#  'disco74': array([-0.0196228 , -0.00567627,  0.00927734, ...,  0.01547241,
#          0.01220703,  0.0319519 ], dtype=float32),
#  'disco75': array([ 0.08364868,  0.0453186 ,  0.00683594, ..., -0.00213623,
#          0.00817871,  0.01608276], dtype=float32),
#  'disco76': array([ 0.01351929, -0.00387573, -0.0055542 , ..., -0.10577393,
#         -0.0737915 , -0.10586548], dtype=float32),
#  'disco77': array([-0.00085449, -0.00628662, -0.01074219, ...,  0.00042725,
#         -0.00393677, -0.00354004], dtype=float32),
#  'disco78': array([ 0.11407471,  0.0262146 , -0.08010864, ..., -0.06292725,
#         -0.00262451, -0.15042114], dtype=float32),
#  'disco79': array([ 0.20974731,  0.13619995,  0.14807129, ..., -0.16918945,
#         -0.19021606, -0.21813965], dtype=float32),
#  'disco80': array([ 0.07867432,  0.12042236,  0.14501953, ..., -0.02474976,
#         -0.02694702, -0.03384399], dtype=float32),
#  'disco81': array([ 0.10012817,  0.07476807,  0.05813599, ..., -0.15820312,
#         -0.20874023, -0.1343689 ], dtype=float32),
#  'disco82': array([ 0.00262451,  0.01730347, -0.01803589, ..., -0.14556885,
#         -0.1444397 , -0.03250122], dtype=float32),
#  'disco83': array([ 0.03485107,  0.08166504,  0.05599976, ..., -0.01049805,
#         -0.00112915,  0.01889038], dtype=float32),
#  'disco84': array([-0.10241699, -0.06164551, -0.11993408, ...,  0.0145874 ,
#          0.07440186, -0.00054932], dtype=float32),
#  'disco85': array([-0.03607178, -0.10568237, -0.20123291, ...,  0.0916748 ,
#          0.08364868,  0.07592773], dtype=float32),
#  'disco86': array([ 0.05020142,  0.06350708,  0.07614136, ..., -0.11071777,
#         -0.0458374 ,  0.02746582], dtype=float32),
#  'disco87': array([-0.171875  , -0.19036865, -0.2199707 , ..., -0.02883911,
#          0.06295776,  0.09494019], dtype=float32),
#  'disco88': array([ 0.1060791 ,  0.08496094,  0.06210327, ..., -0.03277588,
#         -0.00424194,  0.02380371], dtype=float32),
#  'disco89': array([0.03042603, 0.04797363, 0.03930664, ..., 0.06710815, 0.14303589,
#         0.18615723], dtype=float32),
#  'disco90': array([ 0.23965454,  0.25027466,  0.23980713, ..., -0.05026245,
#          0.06378174,  0.06427002], dtype=float32),
#  'disco91': array([ 0.03497314,  0.03442383,  0.03503418, ..., -0.05535889,
#         -0.07684326, -0.08679199], dtype=float32),
#  'disco92': array([-0.21340942, -0.14624023, -0.13067627, ..., -0.02093506,
#         -0.00253296,  0.03979492], dtype=float32),
#  'disco93': array([-0.03149414, -0.08660889, -0.1427002 , ..., -0.12075806,
#         -0.09487915, -0.02420044], dtype=float32),
#  'disco94': array([-0.23202515, -0.23168945, -0.1979065 , ..., -0.17419434,
#         -0.14257812, -0.10617065], dtype=float32),
#  'disco95': array([-0.19454956, -0.2170105 , -0.23977661, ..., -0.00567627,
#         -0.0135498 , -0.00457764], dtype=float32),
#  'disco96': array([ 0.06814575,  0.02600098, -0.02764893, ..., -0.06402588,
#         -0.09243774, -0.07168579], dtype=float32),
#  'disco97': array([-0.16381836, -0.14376831, -0.11804199, ..., -0.29336548,
#         -0.08843994, -0.16705322], dtype=float32),
#  'disco98': array([ 0.03372192,  0.05703735,  0.06817627, ..., -0.00717163,
#          0.00860596,  0.02481079], dtype=float32),
#  'disco99': array([-0.16381836, -0.14376831, -0.11804199, ..., -0.29336548,
#         -0.08843994, -0.16705322], dtype=float32),
#  'blues0': array([-0.1104126 , -0.16241455, -0.11431885, ...,  0.1579895 ,
#          0.0814209 ,  0.08309937], dtype=float32),
#  'blues1': array([ 0.1854248 ,  0.24972534,  0.15673828, ..., -0.03649902,
#         -0.0145874 ,  0.00842285], dtype=float32),
#  'blues2': array([ 0.03570557,  0.05581665,  0.04812622, ..., -0.3829651 ,
#         -0.410614  , -0.39138794], dtype=float32),
#  'blues3': array([-0.07684326, -0.13812256, -0.118927  , ..., -0.04815674,
#         -0.13256836, -0.0440979 ], dtype=float32),
#  'blues4': array([-0.00338745,  0.15115356,  0.18841553, ..., -0.05203247,
#         -0.1149292 , -0.13412476], dtype=float32),
#  'blues5': array([-0.16357422, -0.18377686, -0.14898682, ...,  0.3703308 ,
#          0.38912964,  0.37878418], dtype=float32),
#  'blues6': array([-0.04641724, -0.12106323, -0.13388062, ..., -0.2052002 ,
#         -0.19973755, -0.19302368], dtype=float32),
#  'blues7': array([-0.17077637, -0.27716064, -0.26010132, ...,  0.06536865,
#          0.07171631,  0.06881714], dtype=float32),
#  'blues8': array([ 0.01901245,  0.04769897,  0.02941895, ...,  0.01318359,
#         -0.0663147 , -0.12484741], dtype=float32),
#  'blues9': array([-0.19836426, -0.38546753, -0.2819519 , ..., -0.15209961,
#         -0.08755493,  0.04107666], dtype=float32),
#  'blues10': array([-0.13711548, -0.23635864, -0.2230835 , ...,  0.29779053,
#          0.38290405,  0.48571777], dtype=float32),
#  'blues11': array([-0.07327271, -0.1105957 , -0.10214233, ...,  0.02966309,
#          0.0328064 ,  0.03045654], dtype=float32),
#  'blues12': array([ 0.23739624,  0.36120605,  0.30667114, ...,  0.17504883,
#          0.01113892, -0.18429565], dtype=float32),
#  'blues13': array([-0.02941895, -0.02072144,  0.00424194, ..., -0.07501221,
#         -0.09280396, -0.10250854], dtype=float32),
#  'blues14': array([-0.10806274, -0.15075684, -0.17327881, ..., -0.10281372,
#         -0.09716797, -0.07785034], dtype=float32),
#  'blues15': array([ 0.00799561,  0.0022583 ,  0.01434326, ...,  0.00970459,
#         -0.1585083 , -0.15991211], dtype=float32),
#  'blues16': array([ 0.1822815 ,  0.28302002,  0.21020508, ..., -0.22045898,
#         -0.36273193, -0.4295349 ], dtype=float32),
#  'blues17': array([0.03161621, 0.05133057, 0.0489502 , ..., 0.05999756, 0.0592041 ,
#         0.05136108], dtype=float32),
#  'blues18': array([-0.10046387, -0.15109253, -0.15005493, ...,  0.23175049,
#          0.26260376,  0.25552368], dtype=float32),
#  'blues19': array([-0.13821411, -0.22592163, -0.18408203, ...,  0.01663208,
#          0.02062988, -0.00970459], dtype=float32),
#  'blues20': array([0.04190063, 0.11297607, 0.15304565, ..., 0.02462769, 0.01577759,
#         0.01290894], dtype=float32),
#  'blues21': array([ 0.17184448,  0.20730591,  0.08227539, ...,  0.00271606,
#         -0.02062988, -0.01370239], dtype=float32),
#  'blues22': array([-0.13650513, -0.23358154, -0.21896362, ...,  0.16055298,
#          0.03646851, -0.01699829], dtype=float32),
#  'blues23': array([0.02462769, 0.03604126, 0.02981567, ..., 0.08691406, 0.09509277,
#         0.09503174], dtype=float32),
#  'blues24': array([ 0.01647949,  0.03048706,  0.01889038, ..., -0.12155151,
#         -0.12945557, -0.0958252 ], dtype=float32),
#  'blues25': array([-0.1638794 , -0.28948975, -0.26593018, ...,  0.18536377,
#         -0.32614136, -0.32296753], dtype=float32),
#  'blues26': array([ 0.01290894,  0.00811768, -0.00445557, ..., -0.05819702,
#          0.04946899,  0.16204834], dtype=float32),
#  'blues27': array([ 0.04489136,  0.07424927,  0.06942749, ..., -0.01293945,
#         -0.05969238, -0.08255005], dtype=float32),
#  'blues28': array([-0.00836182, -0.01040649, -0.01641846, ..., -0.09402466,
#         -0.11422729, -0.16644287], dtype=float32),
#  'blues29': array([0.06283569, 0.08822632, 0.08084106, ..., 0.22628784, 0.29864502,
#         0.20721436], dtype=float32),
#  'blues30': array([0.03710938, 0.07446289, 0.07992554, ..., 0.04644775, 0.02532959,
#         0.01647949], dtype=float32),
#  'blues31': array([-0.13864136, -0.20974731, -0.1781311 , ..., -0.09512329,
#         -0.10244751, -0.09643555], dtype=float32),
#  'blues32': array([-0.02020264, -0.03634644, -0.02706909, ...,  0.01159668,
#          0.01779175,  0.04614258], dtype=float32),
#  'blues33': array([-0.24917603, -0.32904053, -0.15524292, ..., -0.30548096,
#         -0.21594238, -0.16586304], dtype=float32),
#  'blues34': array([-0.02090454,  0.01016235,  0.04364014, ..., -0.0977478 ,
#         -0.09606934, -0.08364868], dtype=float32),
#  'blues35': array([ 0.00396729,  0.00012207,  0.0166626 , ..., -0.03201294,
#         -0.02890015, -0.03329468], dtype=float32),
#  'blues36': array([ 0.07894897,  0.13638306,  0.13336182, ..., -0.01293945,
#         -0.00521851,  0.00741577], dtype=float32),
#  'blues37': array([ 0.0017395 ,  0.00390625,  0.00375366, ..., -0.08197021,
#         -0.14053345, -0.17556763], dtype=float32),
#  'blues38': array([-0.01300049, -0.03060913, -0.03607178, ...,  0.0098877 ,
#          0.01107788,  0.0118103 ], dtype=float32),
#  'blues39': array([ 0.01705933,  0.03436279,  0.03353882, ..., -0.03640747,
#         -0.01687622, -0.00280762], dtype=float32),
#  'blues40': array([-0.04974365, -0.08596802, -0.08615112, ..., -0.11828613,
#         -0.1229248 , -0.11422729], dtype=float32),
#  'blues41': array([-0.10031128, -0.1550293 , -0.12982178, ...,  0.01651001,
#          0.02737427,  0.02514648], dtype=float32),
#  'blues42': array([0.01138306, 0.02175903, 0.0100708 , ..., 0.12051392, 0.16903687,
#         0.1708374 ], dtype=float32),
#  'blues43': array([0.00588989, 0.00765991, 0.0012207 , ..., 0.06884766, 0.04101562,
#         0.01550293], dtype=float32),
#  'blues44': array([-0.236969  , -0.296875  , -0.08099365, ...,  0.4902649 ,
#          0.5562134 ,  0.6029663 ], dtype=float32),
#  'blues45': array([-0.23886108, -0.41534424, -0.3161621 , ..., -0.00558472,
#         -0.00338745, -0.01620483], dtype=float32),
#  'blues46': array([-0.01089478, -0.01052856, -0.00549316, ..., -0.10565186,
#         -0.10415649, -0.02426147], dtype=float32),
#  'blues47': array([0.06060791, 0.08435059, 0.06304932, ..., 0.01937866, 0.01895142,
#         0.02755737], dtype=float32),
#  'blues48': array([ 0.15414429,  0.1751709 ,  0.0730896 , ..., -0.2531128 ,
#         -0.2521057 , -0.13058472], dtype=float32),
#  'blues49': array([-0.01669312, -0.02764893, -0.02191162, ...,  0.12365723,
#          0.13430786,  0.1262207 ], dtype=float32),
#  'blues50': array([-0.01055908, -0.01623535, -0.012146  , ...,  0.0675354 ,
#          0.07672119,  0.07815552], dtype=float32),
#  'blues51': array([ 0.02215576, -0.02536011, -0.0512085 , ...,  0.04190063,
#          0.06417847,  0.07730103], dtype=float32),
#  'blues52': array([ 0.21246338,  0.31881714,  0.17388916, ..., -0.03594971,
#         -0.04187012, -0.02597046], dtype=float32),
#  'blues53': array([0.10144043, 0.16815186, 0.14266968, ..., 0.03466797, 0.0324707 ,
#         0.03112793], dtype=float32),
#  'blues54': array([ 0.04647827,  0.06399536,  0.04327393, ..., -0.04052734,
#         -0.03955078, -0.03741455], dtype=float32),
#  'blues55': array([ 0.12524414,  0.18426514,  0.09741211, ..., -0.10821533,
#         -0.17260742, -0.18206787], dtype=float32),
#  'blues56': array([-0.00299072,  0.00485229,  0.00845337, ..., -0.06799316,
#         -0.09191895, -0.0987854 ], dtype=float32),
#  'blues57': array([0.17141724, 0.23706055, 0.10256958, ..., 0.02780151, 0.06393433,
#         0.06265259], dtype=float32),
#  'blues58': array([0.23117065, 0.3553772 , 0.30532837, ..., 0.01785278, 0.02093506,
#         0.01852417], dtype=float32),
#  'blues59': array([-0.00332642, -0.01135254, -0.00799561, ...,  0.00863647,
#          0.01904297,  0.02990723], dtype=float32),
#  'blues60': array([0.25909424, 0.48797607, 0.5100403 , ..., 0.5618286 , 0.7053833 ,
#         0.5423889 ], dtype=float32),
#  'blues61': array([-0.03634644, -0.05361938, -0.04153442, ..., -0.10464478,
#         -0.15408325, -0.17166138], dtype=float32),
#  'blues62': array([-0.02502441, -0.15545654, -0.22753906, ..., -0.0088501 ,
#         -0.01254272, -0.05499268], dtype=float32),
#  'blues63': array([-0.01901245, -0.04046631, -0.05606079, ..., -0.02963257,
#          0.0111084 ,  0.00811768], dtype=float32),
#  'blues64': array([0.07705688, 0.11590576, 0.09234619, ..., 0.07122803, 0.06323242,
#         0.04721069], dtype=float32),
#  'blues65': array([-0.00631714, -0.00927734, -0.0083313 , ...,  0.04135132,
#          0.05197144,  0.05496216], dtype=float32),
#  'blues66': array([ 0.00479126,  0.05578613,  0.12127686, ..., -0.00210571,
#         -0.00653076,  0.0010376 ], dtype=float32),
#  'blues67': array([-0.16659546, -0.23223877, -0.2239685 , ..., -0.06652832,
#         -0.06881714, -0.06912231], dtype=float32),
#  'blues68': array([0.0552063 , 0.08731079, 0.07107544, ..., 0.02307129, 0.03149414,
#         0.01797485], dtype=float32),
#  'blues69': array([ 0.09863281,  0.15170288,  0.12884521, ..., -0.06152344,
#         -0.06439209, -0.06393433], dtype=float32),
#  'blues70': array([0.12014771, 0.14956665, 0.10458374, ..., 0.01803589, 0.01541138,
#         0.01037598], dtype=float32),
#  'blues71': array([-0.03082275, -0.03540039, -0.03076172, ...,  0.00561523,
#          0.00332642, -0.00238037], dtype=float32),
#  'blues72': array([-0.05612183, -0.13653564, -0.17175293, ...,  0.00213623,
#          0.00097656,  0.0088501 ], dtype=float32),
#  'blues73': array([-0.5245056 , -0.81640625, -0.5826111 , ..., -0.03433228,
#         -0.0274353 , -0.03268433], dtype=float32),
#  'blues74': array([-0.0005188 ,  0.00067139, -0.00146484, ..., -0.02835083,
#         -0.02896118, -0.02661133], dtype=float32),
#  'blues75': array([0.01361084, 0.02810669, 0.03515625, ..., 0.03616333, 0.03378296,
#         0.04040527], dtype=float32),
#  'blues76': array([ 0.06378174,  0.08837891,  0.04940796, ..., -0.17605591,
#         -0.14416504, -0.15023804], dtype=float32),
#  'blues77': array([-0.00015259,  0.00466919,  0.01028442, ..., -0.00985718,
#         -0.009552  , -0.01708984], dtype=float32),
#  'blues78': array([-0.21359253, -0.35723877, -0.31430054, ..., -0.0574646 ,
#         -0.01867676, -0.01022339], dtype=float32),
#  'blues79': array([ 0.00732422,  0.01660156,  0.00762939, ..., -0.05560303,
#         -0.06106567, -0.06417847], dtype=float32),
#  'blues80': array([-0.02560425, -0.03881836, -0.03527832, ..., -0.03973389,
#         -0.04290771, -0.04257202], dtype=float32),
#  'blues81': array([-0.0980835 , -0.08453369, -0.06008911, ..., -0.07894897,
#         -0.11987305, -0.04449463], dtype=float32),
# ...
#  'country73': array([-0.07571411, -0.1192627 , -0.10812378, ...,  0.00549316,
#          0.01937866,  0.05264282], dtype=float32),
#  'country74': array([-0.03689575, -0.03115845, -0.02194214, ...,  0.01855469,
#          0.02093506,  0.02236938], dtype=float32),
#  'country75': array([-0.02590942, -0.04568481, -0.05706787, ...,  0.09643555,
#          0.0819397 ,  0.05276489], dtype=float32),
#  'country76': array([0.02719116, 0.04751587, 0.04974365, ..., 0.07989502, 0.09991455,
#         0.10647583], dtype=float32),
#  'country77': array([-0.00280762, -0.01260376, -0.01239014, ...,  0.11737061,
#          0.13104248,  0.1262207 ], dtype=float32),
#  'country78': array([ 0.04074097,  0.12823486, -0.0043335 , ..., -0.21664429,
#          0.17156982,  0.35287476], dtype=float32),
#  'country79': array([-0.13415527, -0.19485474, -0.04257202, ...,  0.2260437 ,
#          0.15042114,  0.04238892], dtype=float32),
#  'country80': array([-0.00799561, -0.01971436, -0.03125   , ...,  0.03573608,
#         -0.03222656, -0.08355713], dtype=float32),
#  'country81': array([0.10247803, 0.08059692, 0.10037231, ..., 0.08895874, 0.11795044,
#         0.16305542], dtype=float32),
#  'country82': array([ 0.04135132,  0.04818726,  0.05679321, ..., -0.05780029,
#         -0.01217651, -0.01144409], dtype=float32),
#  'country83': array([ 0.06518555,  0.10369873,  0.07818604, ..., -0.11758423,
#         -0.1076355 , -0.11001587], dtype=float32),
#  'country84': array([-0.02520752, -0.04940796, -0.09365845, ..., -0.00665283,
#         -0.00283813,  0.00167847], dtype=float32),
#  'country85': array([ 0.07885742,  0.16244507,  0.17645264, ..., -0.04745483,
#         -0.03637695, -0.02728271], dtype=float32),
#  'country86': array([0.09033203, 0.11953735, 0.10821533, ..., 0.00473022, 0.06304932,
#         0.11682129], dtype=float32),
#  'country87': array([-0.01025391,  0.0994873 ,  0.26113892, ..., -0.04290771,
#         -0.12988281, -0.0798645 ], dtype=float32),
#  'country88': array([-0.00131226, -0.00311279, -0.00738525, ..., -0.04379272,
#         -0.04467773, -0.04608154], dtype=float32),
#  'country89': array([ 0.02011108,  0.03500366,  0.0355835 , ..., -0.02651978,
#         -0.09307861, -0.12701416], dtype=float32),
#  'country90': array([-0.1423645 , -0.2215271 , -0.11950684, ..., -0.07403564,
#         -0.20462036, -0.09301758], dtype=float32),
#  'country91': array([-0.01470947, -0.04962158, -0.05966187, ...,  0.36569214,
#          0.43154907,  0.472229  ], dtype=float32),
#  'country92': array([ 0.02487183,  0.0380249 ,  0.02770996, ..., -0.02423096,
#         -0.02633667, -0.03213501], dtype=float32),
#  'country93': array([0.09390259, 0.09164429, 0.09054565, ..., 0.01123047, 0.01434326,
#         0.01702881], dtype=float32),
#  'country94': array([-0.03762817, -0.03610229, -0.03848267, ...,  0.03826904,
#          0.05709839,  0.02935791], dtype=float32),
#  'country95': array([-0.13919067, -0.11087036, -0.08920288, ...,  0.21487427,
#          0.20837402,  0.04736328], dtype=float32),
#  'country96': array([-0.12936401, -0.21520996, -0.20806885, ...,  0.11901855,
#          0.07955933,  0.04376221], dtype=float32),
#  'country97': array([-0.01907349,  0.01107788, -0.00460815, ...,  0.18780518,
#          0.21450806,  0.2159729 ], dtype=float32),
#  'country98': array([-0.17755127, -0.2388916 , -0.15670776, ..., -0.69537354,
#         -0.71554565, -0.65075684], dtype=float32),
#  'country99': array([-0.05899048, -0.0944519 , -0.07345581, ..., -0.00662231,
#         -0.01599121, -0.04220581], dtype=float32),
#  'jazz0': array([0.1663208 , 0.16705322, 0.20510864, ..., 0.4413147 , 0.42208862,
#         0.37982178], dtype=float32),
#  'jazz1': array([0.04568481, 0.05960083, 0.03372192, ..., 0.00091553, 0.00024414,
#         0.00125122], dtype=float32),
#  'jazz2': array([ 0.02526855,  0.02520752,  0.02957153, ...,  0.04119873,
#         -0.01599121,  0.04489136], dtype=float32),
#  'jazz3': array([0.12203979, 0.22442627, 0.19665527, ..., 0.0116272 , 0.03677368,
#         0.05535889], dtype=float32),
#  'jazz4': array([-0.04998779, -0.04193115, -0.02993774, ..., -0.01553345,
#         -0.01965332, -0.02023315], dtype=float32),
#  'jazz5': array([-0.11004639, -0.18771362, -0.17840576, ..., -0.03662109,
#         -0.03503418, -0.03079224], dtype=float32),
#  'jazz6': array([-0.15530396, -0.21246338, -0.08627319, ..., -0.0489502 ,
#         -0.0569458 , -0.0592041 ], dtype=float32),
#  'jazz7': array([ 0.00747681, -0.00967407, -0.01113892, ...,  0.01791382,
#          0.01971436,  0.01654053], dtype=float32),
#  'jazz8': array([ 0.00662231,  0.01126099,  0.01037598, ..., -0.02328491,
#         -0.02392578, -0.02212524], dtype=float32),
#  'jazz9': array([-0.15301514, -0.17422485, -0.18338013, ..., -0.03778076,
#         -0.0340271 , -0.03158569], dtype=float32),
#  'jazz10': array([-0.03521729, -0.03540039,  0.01885986, ...,  0.08673096,
#          0.08920288,  0.08895874], dtype=float32),
#  'jazz11': array([-0.00924683, -0.01177979, -0.01370239, ...,  0.0071106 ,
#          0.00561523,  0.00561523], dtype=float32),
#  'jazz12': array([ 0.04055786,  0.0703125 ,  0.07653809, ..., -0.13601685,
#         -0.17391968, -0.16320801], dtype=float32),
#  'jazz13': array([-0.06362915, -0.03799438, -0.04327393, ..., -0.04537964,
#         -0.04827881, -0.04840088], dtype=float32),
#  'jazz14': array([0.04501343, 0.07720947, 0.05825806, ..., 0.04803467, 0.05303955,
#         0.05331421], dtype=float32),
#  'jazz15': array([-0.07281494, -0.00500488, -0.06283569, ..., -0.03079224,
#         -0.02597046, -0.03338623], dtype=float32),
#  'jazz16': array([-0.01861572, -0.0229187 , -0.00646973, ..., -0.30789185,
#         -0.28320312, -0.222229  ], dtype=float32),
#  'jazz17': array([-0.03207397, -0.05758667, -0.04592896, ..., -0.0112915 ,
#         -0.01727295, -0.02252197], dtype=float32),
#  'jazz18': array([ 0.00827026,  0.01028442,  0.00604248, ..., -0.02148438,
#         -0.02160645, -0.02804565], dtype=float32),
#  'jazz19': array([-0.02023315, -0.05187988, -0.07672119, ...,  0.01208496,
#          0.01571655,  0.01812744], dtype=float32),
#  'jazz20': array([-0.13595581, -0.09390259, -0.06210327, ...,  0.29577637,
#          0.23522949,  0.2368164 ], dtype=float32),
#  'jazz21': array([0.00241089, 0.00549316, 0.00866699, ..., 0.00201416, 0.00250244,
#         0.00119019], dtype=float32),
#  'jazz22': array([-0.03414917, -0.04660034, -0.02764893, ..., -0.01467896,
#         -0.02035522, -0.01965332], dtype=float32),
#  'jazz23': array([ 0.22244263,  0.05227661, -0.05319214, ..., -0.40270996,
#         -0.40472412, -0.40567017], dtype=float32),
#  'jazz24': array([ 0.02279663,  0.03564453,  0.02920532, ..., -0.01782227,
#         -0.01934814, -0.01861572], dtype=float32),
#  'jazz25': array([ 0.02398682,  0.02374268,  0.02572632, ..., -0.04324341,
#         -0.09570312, -0.05776978], dtype=float32),
#  'jazz26': array([-0.13952637, -0.13168335, -0.14813232, ...,  0.07772827,
#          0.06713867,  0.07391357], dtype=float32),
#  'jazz27': array([ 0.02026367,  0.01330566,  0.0038147 , ..., -0.02258301,
#         -0.01541138, -0.00942993], dtype=float32),
#  'jazz28': array([0.09072876, 0.13885498, 0.08273315, ..., 0.16775513, 0.17504883,
#         0.16122437], dtype=float32),
#  'jazz29': array([-0.05102539, -0.05874634, -0.0352478 , ..., -0.10687256,
#         -0.11016846, -0.10769653], dtype=float32),
#  'jazz30': array([ 0.08435059,  0.03036499,  0.00839233, ..., -0.21139526,
#         -0.21560669, -0.21411133], dtype=float32),
#  'jazz31': array([-0.02191162, -0.03909302, -0.03326416, ..., -0.03543091,
#         -0.0378418 , -0.03274536], dtype=float32),
#  'jazz32': array([ 0.00921631,  0.00726318, -0.00234985, ...,  0.00167847,
#         -0.03924561, -0.05404663], dtype=float32),
#  'jazz33': array([ 0.06652832,  0.16467285,  0.2319336 , ...,  0.00335693,
#         -0.00650024, -0.00723267], dtype=float32),
#  'jazz34': array([ 0.2270813 ,  0.20773315,  0.19116211, ..., -0.07705688,
#         -0.06759644, -0.07684326], dtype=float32),
#  'jazz35': array([-0.08374023, -0.12731934, -0.10482788, ...,  0.07290649,
#          0.03701782,  0.00262451], dtype=float32),
#  'jazz36': array([0.02145386, 0.04266357, 0.04168701, ..., 0.00390625, 0.0065918 ,
#         0.01400757], dtype=float32),
#  'jazz37': array([-0.01693726, -0.03903198, -0.05743408, ..., -0.02923584,
#         -0.02664185, -0.01321411], dtype=float32),
#  'jazz38': array([-0.00039673,  0.00686646,  0.00769043, ...,  0.04067993,
#          0.01364136, -0.01196289], dtype=float32),
#  'jazz39': array([-0.11947632, -0.11639404, -0.10928345, ...,  0.07235718,
#          0.03713989,  0.00350952], dtype=float32),
#  'jazz40': array([-0.03106689, -0.05078125, -0.04537964, ...,  0.05258179,
#          0.0463562 ,  0.04959106], dtype=float32),
#  'jazz41': array([-0.09240723, -0.06481934, -0.06246948, ...,  0.05194092,
#          0.04388428,  0.03231812], dtype=float32),
#  'jazz42': array([-0.01385498, -0.00756836,  0.00662231, ..., -0.04138184,
#         -0.0425415 , -0.03778076], dtype=float32),
#  'jazz43': array([0.01177979, 0.01397705, 0.0189209 , ..., 0.07901001, 0.08682251,
#         0.0871582 ], dtype=float32),
#  'jazz44': array([0.05685425, 0.07565308, 0.0402832 , ..., 0.03833008, 0.03411865,
#         0.02548218], dtype=float32),
#  'jazz45': array([-0.05224609,  0.04705811,  0.09838867, ...,  0.05691528,
#          0.06399536,  0.07427979], dtype=float32),
#  'jazz46': array([-0.00814819, -0.00872803, -0.00909424, ..., -0.0302124 ,
#         -0.04754639, -0.05554199], dtype=float32),
#  'jazz47': array([3.0517578e-05, 1.8920898e-02, 2.6275635e-02, ..., 7.5805664e-02,
#         5.7708740e-02, 4.6691895e-03], dtype=float32),
#  'jazz48': array([-0.20962524, -0.3809204 , -0.39624023, ...,  0.03085327,
#          0.02249146,  0.00622559], dtype=float32),
#  'jazz49': array([-0.02954102, -0.07070923, -0.10971069, ...,  0.06945801,
#         -0.19406128, -0.08355713], dtype=float32),
#  'jazz50': array([ 0.03045654,  0.01077271, -0.00854492, ..., -0.01879883,
#         -0.00799561, -0.00091553], dtype=float32),
#  'jazz51': array([-0.02191162, -0.03604126, -0.03900146, ...,  0.02438354,
#          0.03466797,  0.03918457], dtype=float32),
#  'jazz52': array([-0.0406189 , -0.04577637, -0.03967285, ..., -0.04379272,
#         -0.05010986, -0.04797363], dtype=float32),
#  'jazz53': array([ 0.0632019 ,  0.05630493,  0.04446411, ..., -0.12527466,
#         -0.13815308, -0.14428711], dtype=float32),
#  'jazz54': array([ 0.10202026,  0.10891724,  0.11755371, ..., -0.02044678,
#         -0.03045654, -0.00079346], dtype=float32),
#  'jazz55': array([-0.01531982, -0.02963257, -0.0244751 , ..., -0.02853394,
#         -0.00613403, -0.00463867], dtype=float32),
#  'jazz56': array([ 0.08502197,  0.14257812,  0.15310669, ..., -0.01849365,
#         -0.02334595, -0.02868652], dtype=float32),
#  'jazz57': array([ 0.07397461,  0.06695557,  0.0567627 , ..., -0.00305176,
#         -0.00015259,  0.00292969], dtype=float32),
#  'jazz58': array([-0.02023315, -0.03991699, -0.03979492, ...,  0.10791016,
#          0.11074829,  0.0932312 ], dtype=float32),
#  'jazz59': array([-0.00869751, -0.00927734, -0.0045166 , ...,  0.01208496,
#          0.00427246, -0.00296021], dtype=float32),
#  'jazz60': array([0.00335693, 0.00491333, 0.00378418, ..., 0.05691528, 0.05136108,
#         0.03808594], dtype=float32),
#  'jazz61': array([ 0.06201172,  0.06365967,  0.07931519, ..., -0.14196777,
#         -0.16790771, -0.16546631], dtype=float32),
#  'jazz62': array([-0.03860474, -0.05270386, -0.02633667, ..., -0.0128479 ,
#         -0.01394653, -0.01269531], dtype=float32),
#  'jazz63': array([-0.07733154, -0.0501709 , -0.03863525, ..., -0.1109314 ,
#         -0.105896  , -0.1078186 ], dtype=float32),
#  'jazz64': array([ 0.05099487,  0.07406616,  0.0536499 , ..., -0.00369263,
#         -0.00012207,  0.00216675], dtype=float32),
#  'jazz65': array([ 0.00198364,  0.00143433, -0.00170898, ...,  0.03482056,
#          0.03631592,  0.0345459 ], dtype=float32),
#  'jazz66': array([ 0.00402832,  0.00827026,  0.01098633, ..., -0.25946045,
#         -0.21722412, -0.17755127], dtype=float32),
#  'jazz67': array([-0.03375244, -0.02975464, -0.03762817, ..., -0.11248779,
#         -0.1479187 , -0.17633057], dtype=float32),
#  'jazz68': array([-0.02554321, -0.07177734, -0.11016846, ...,  0.00189209,
#         -0.11181641, -0.1611023 ], dtype=float32),
#  'jazz69': array([-0.06143188, -0.09420776, -0.0791626 , ...,  0.01300049,
#          0.06283569,  0.09320068], dtype=float32),
#  'jazz70': array([0.06491089, 0.06274414, 0.0592041 , ..., 0.05526733, 0.05007935,
#         0.04986572], dtype=float32),
#  'jazz71': array([ 0.00115967,  0.00067139, -0.00418091, ..., -0.04638672,
#         -0.04507446, -0.04168701], dtype=float32),
#  'jazz72': array([-0.06072998, -0.06820679, -0.16693115, ...,  0.11166382,
#          0.03173828,  0.04846191], dtype=float32),
#  'jazz73': array([ 0.0350647 ,  0.03735352,  0.03372192, ...,  0.02325439,
#         -0.00863647, -0.01925659], dtype=float32),
#  'jazz74': array([0.08334351, 0.14605713, 0.14706421, ..., 0.0085144 , 0.00469971,
#         0.00369263], dtype=float32),
#  'jazz75': array([-0.01397705, -0.03887939, -0.03973389, ...,  0.00802612,
#          0.00921631,  0.00939941], dtype=float32),
#  'jazz76': array([-0.0062561 , -0.00891113, -0.00772095, ..., -0.19158936,
#         -0.20874023, -0.20449829], dtype=float32),
#  'jazz77': array([-0.07580566, -0.10604858, -0.07144165, ...,  0.10879517,
#          0.03897095,  0.03817749], dtype=float32),
#  'jazz78': array([-0.01635742, -0.02282715, -0.01467896, ...,  0.05389404,
#          0.068573  ,  0.06707764], dtype=float32),
#  'jazz79': array([-0.01028442, -0.01870728, -0.01431274, ..., -0.07843018,
#         -0.07788086, -0.05490112], dtype=float32),
#  'jazz80': array([-0.00344849, -0.00244141, -0.00158691, ..., -0.01519775,
#          0.04669189,  0.05368042], dtype=float32),
#  'jazz81': array([-0.02810669, -0.03747559,  0.01904297, ...,  0.08370972,
#          0.09231567,  0.08880615], dtype=float32),
#  'jazz82': array([-0.28155518, -0.3609314 , -0.4019165 , ...,  0.03143311,
#          0.02233887,  0.00592041], dtype=float32),
#  'jazz83': array([-0.03488159, -0.04223633,  0.00186157, ..., -0.02185059,
#          0.02493286,  0.06051636], dtype=float32),
#  'jazz84': array([-0.02368164, -0.0335083 , -0.02297974, ..., -0.09701538,
#         -0.05914307, -0.01776123], dtype=float32),
#  'jazz85': array([-0.01733398, -0.02090454, -0.01681519, ..., -0.10110474,
#         -0.10919189, -0.10134888], dtype=float32),
#  'jazz86': array([-0.04281616, -0.06454468, -0.05288696, ..., -0.00152588,
#         -0.00405884, -0.00592041], dtype=float32),
#  'jazz87': array([-0.06265259, -0.05786133, -0.05596924, ..., -0.00128174,
#         -0.00396729, -0.00643921], dtype=float32),
#  'jazz88': array([-0.00979614, -0.00924683,  0.00430298, ..., -0.00680542,
#         -0.05853271, -0.06491089], dtype=float32),
#  'jazz89': array([ 0.06414795, -0.00982666,  0.08511353, ...,  0.00830078,
#         -0.02224731, -0.03018188], dtype=float32),
#  'jazz90': array([ 0.0295105 ,  0.04818726,  0.04190063, ..., -0.02545166,
#         -0.02603149, -0.02374268], dtype=float32),
#  'jazz91': array([-0.00216675, -0.03436279, -0.03268433, ...,  0.41540527,
#          0.4043274 ,  0.40255737], dtype=float32),
#  'jazz92': array([-0.06219482, -0.09188843, -0.072052  , ...,  0.05307007,
#          0.05627441,  0.05758667], dtype=float32),
#  'jazz93': array([ 0.08837891,  0.00109863,  0.08291626, ...,  0.02581787,
#         -0.03207397, -0.09005737], dtype=float32),
#  'jazz94': array([ 0.05029297,  0.04327393,  0.00137329, ..., -0.2033081 ,
#         -0.22244263, -0.21456909], dtype=float32),
#  'jazz95': array([ 0.01651001,  0.02923584,  0.03015137, ..., -0.00790405,
#         -0.00375366,  0.01220703], dtype=float32),
#  'jazz96': array([0.09100342, 0.08599854, 0.08410645, ..., 0.08886719, 0.07849121,
#         0.06893921], dtype=float32),
#  'jazz97': array([ 0.02148438,  0.003479  , -0.00161743, ..., -0.19900513,
#         -0.03552246,  0.10549927], dtype=float32),
#  'jazz98': array([ 0.04382324,  0.06265259,  0.04187012, ..., -0.11987305,
#         -0.14324951, -0.14401245], dtype=float32),
#  'jazz99': array([0.02557373, 0.04382324, 0.03601074, ..., 0.08731079, 0.11334229,
#         0.12271118], dtype=float32)}

# %%
# 데이터별 특징추출
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
datas = []
Y = []
for i, i1 in wave_files.items():
    for j in i1:
        data = os.path.join(i, j)
        y, sr = librosa.load(data)
        chroma_stft = np.mean(librosa.feature.chroma_stft(y=y, sr=sr))
        rmse = np.mean(librosa.feature.rms(y=y))
        spec_cent = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))
        spec_bw = np.mean(librosa.feature.spectral_bandwidth(y=y, sr=sr))
        rolloff = np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr))
        zcr = np.mean(librosa.feature.zero_crossing_rate(y))
        datas.append({
        "path":data,
        "filename":j,
        "chroma_stft":chroma_stft,
        "rmse":rmse,
        "spec_cent":spec_cent,
        "spec_bw":spec_bw,
        "rolloff":rolloff,
        "zcr":zcr
        })
        Y.append(i)

# %%
df = pd.DataFrame(datas)
df
# Out:
#                                  path       filename  chroma_stft      rmse
# 0      ./data/genres/pop/pop.00080.au   pop.00080.au     0.433540  0.215662  \
# 1      ./data/genres/pop/pop.00022.au   pop.00022.au     0.386972  0.196038
# 2      ./data/genres/pop/pop.00073.au   pop.00073.au     0.423550  0.259782
# 3      ./data/genres/pop/pop.00047.au   pop.00047.au     0.433407  0.215733
# 4      ./data/genres/pop/pop.00016.au   pop.00016.au     0.388811  0.146568
# ..                                ...            ...          ...       ...
# 995  ./data/genres/jazz/jazz.00027.au  jazz.00027.au     0.325170  0.040594
# 996  ./data/genres/jazz/jazz.00076.au  jazz.00076.au     0.303217  0.119098
# 997  ./data/genres/jazz/jazz.00085.au  jazz.00085.au     0.325428  0.071379
# 998  ./data/genres/jazz/jazz.00042.au  jazz.00042.au     0.285201  0.099492
# 999  ./data/genres/jazz/jazz.00013.au  jazz.00013.au     0.314369  0.055462
#
#        spec_cent      spec_bw      rolloff       zcr
# 0    3151.406048  3220.623382  7294.559912  0.127557
# 1    3206.647959  3126.207007  7019.799238  0.141531
# 2    3669.810467  3295.063699  7876.372739  0.161797
# 3    3151.342623  3220.369559  7293.569019  0.127355
# 4    3488.897943  3205.348889  7496.760520  0.153314
# ..           ...          ...          ...       ...
# 995  1769.428268  2113.360398  3966.439331  0.062681
# 996  1733.735682  2068.216050  3379.971802  0.068700
# 997  2860.683151  2566.170784  5605.161054  0.147559
# 998  1344.620126  1548.989660  2773.095193  0.061186
# 999  1790.243641  2313.009872  4398.177555  0.061076
#
# [1000 rows x 8 columns]

# %%
head_mfcc = []
for i in range(1, 21):
    head_mfcc.append(f'mfcc{i}')

# %%
head_mfcc
# Out:
# ['mfcc1',
#  'mfcc2',
#  'mfcc3',
#  'mfcc4',
#  'mfcc5',
#  'mfcc6',
#  'mfcc7',
#  'mfcc8',
#  'mfcc9',
#  'mfcc10',
#  'mfcc11',
#  'mfcc12',
#  'mfcc13',
#  'mfcc14',
#  'mfcc15',
#  'mfcc16',
#  'mfcc17',
#  'mfcc18',
#  'mfcc19',
#  'mfcc20']

# %%
datas_mfcc = []
Y = []
for i, i1 in wave_files.items():
    for j in i1:
        data = os.path.join(i, j)
        y, sr = librosa.load(data)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        mfccs = {}
        for e in range(0,len(mfcc)):
            mfccs[head_mfcc[e]]=np.mean(mfcc[e])
        datas_tmp={
        "path":data,
        "filename":j
        }
        datas_tmp = dict(datas_tmp, **mfccs)
        datas_mfcc.append(datas_tmp)
        Y.append(i)

# %%
df_mfcc = pd.DataFrame(datas_mfcc)
df_mfcc
# Out:
#                                  path       filename       mfcc1       mfcc2
# 0      ./data/genres/pop/pop.00080.au   pop.00080.au  -44.986889   69.775894  \
# 1      ./data/genres/pop/pop.00022.au   pop.00022.au  -45.730503   65.273964
# 2      ./data/genres/pop/pop.00073.au   pop.00073.au   -8.573006   54.295788
# 3      ./data/genres/pop/pop.00047.au   pop.00047.au  -45.029282   69.754700
# 4      ./data/genres/pop/pop.00016.au   pop.00016.au  -97.053978   51.834522
# ..                                ...            ...         ...         ...
# 995  ./data/genres/jazz/jazz.00027.au  jazz.00027.au -262.107971  108.990540
# 996  ./data/genres/jazz/jazz.00076.au  jazz.00076.au -154.338120  110.678246
# 997  ./data/genres/jazz/jazz.00085.au  jazz.00085.au -131.905045   61.607956
# 998  ./data/genres/jazz/jazz.00042.au  jazz.00042.au -206.794632  141.817047
# 999  ./data/genres/jazz/jazz.00013.au  jazz.00013.au -217.636307  112.630753
#
#          mfcc3      mfcc4      mfcc5      mfcc6      mfcc7      mfcc8  ...
# 0    11.840672   8.117906  12.628617   7.812101  11.339221   0.184832  ...  \
# 1    12.928245  14.523945   7.032850   4.394629   6.623768   3.299115  ...
# 2    20.964115  13.100406   9.715855   6.022177  10.730787   6.106817  ...
# 3    11.873838   8.160096  12.596263   7.755170  11.303385   0.250894  ...
# 4    18.751598  20.487318   5.610611   3.575838   5.573987   0.740907  ...
# ..         ...        ...        ...        ...        ...        ...  ...
# 995  -6.340923  55.173943 -10.668641  18.520815  -4.250780  18.553394  ...
# 996 -22.296112  21.155048   4.270861   4.751124  -4.084911  -1.013927  ...
# 997 -12.676340  35.073761  -2.141258  -0.957465  -4.841936  -4.111722  ...
# 998 -13.789803  49.324589 -24.800512  11.800834 -12.790984 -16.550760  ...
# 999  12.674138  39.518566  -9.819439  17.370190 -12.366685  20.703709  ...
#
#         mfcc11     mfcc12    mfcc13    mfcc14    mfcc15     mfcc16    mfcc17
# 0     3.853339  -0.841709  2.132197  1.083205 -0.077104   0.648073 -1.484534  \
# 1     3.662518   2.602134  4.048971  2.384604  1.780818  -2.392593 -1.346176
# 2    -3.447254   0.874806 -1.936897 -2.783130 -2.666644  -3.311479  1.708261
# 3     3.856647  -0.844541  2.099680  1.122588  0.006671   0.748260 -1.474304
# 4    -2.697902  -0.441958 -1.084060 -3.450706 -2.475977  -3.302751 -2.228499
# ..         ...        ...       ...       ...       ...        ...       ...
# 995 -10.986871  11.923828 -3.433859  7.191704 -8.850466   4.982307 -4.036403
# 996  -3.630606  -5.505905  0.538993 -0.509386 -4.806393 -11.206601 -3.936800
# 997   6.401213   3.414421 -2.899613  3.227199 -1.338827   0.875506  3.679272
# 998  -7.660741  -1.378526 -9.349154 -7.501380 -2.871112  -6.142300 -0.939825
# 999 -10.015160   9.042705 -6.878432  7.313042 -4.784163   8.559465 -2.779625
#
#        mfcc18    mfcc19     mfcc20
# 0    3.725630  4.553656   4.274244
# 1   -2.879179 -0.849864  -2.598134
# 2   -0.152766  4.846820   2.906235
# 3    3.672843  4.469373   4.198666
# 4   -2.649556 -2.744086   0.305748
# ..        ...       ...        ...
# 995 -0.111063 -0.818210  -0.612190
# 996 -1.469241 -4.413507 -10.597857
# 997  0.648434 -0.353716   6.321081
# 998 -1.298267 -2.241966  -3.270761
# 999  1.276796 -0.356219   0.349866
#
# [1000 rows x 22 columns]

# %%
df_all = pd.merge(df,df_mfcc)
df_all
# Out:
#                                  path       filename  chroma_stft      rmse
# 0      ./data/genres/pop/pop.00080.au   pop.00080.au     0.433540  0.215662  \
# 1      ./data/genres/pop/pop.00022.au   pop.00022.au     0.386972  0.196038
# 2      ./data/genres/pop/pop.00073.au   pop.00073.au     0.423550  0.259782
# 3      ./data/genres/pop/pop.00047.au   pop.00047.au     0.433407  0.215733
# 4      ./data/genres/pop/pop.00016.au   pop.00016.au     0.388811  0.146568
# ..                                ...            ...          ...       ...
# 995  ./data/genres/jazz/jazz.00027.au  jazz.00027.au     0.325170  0.040594
# 996  ./data/genres/jazz/jazz.00076.au  jazz.00076.au     0.303217  0.119098
# 997  ./data/genres/jazz/jazz.00085.au  jazz.00085.au     0.325428  0.071379
# 998  ./data/genres/jazz/jazz.00042.au  jazz.00042.au     0.285201  0.099492
# 999  ./data/genres/jazz/jazz.00013.au  jazz.00013.au     0.314369  0.055462
#
#        spec_cent      spec_bw      rolloff       zcr       mfcc1       mfcc2
# 0    3151.406048  3220.623382  7294.559912  0.127557  -44.986889   69.775894  \
# 1    3206.647959  3126.207007  7019.799238  0.141531  -45.730503   65.273964
# 2    3669.810467  3295.063699  7876.372739  0.161797   -8.573006   54.295788
# 3    3151.342623  3220.369559  7293.569019  0.127355  -45.029282   69.754700
# 4    3488.897943  3205.348889  7496.760520  0.153314  -97.053978   51.834522
# ..           ...          ...          ...       ...         ...         ...
# 995  1769.428268  2113.360398  3966.439331  0.062681 -262.107971  108.990540
# 996  1733.735682  2068.216050  3379.971802  0.068700 -154.338120  110.678246
# 997  2860.683151  2566.170784  5605.161054  0.147559 -131.905045   61.607956
# 998  1344.620126  1548.989660  2773.095193  0.061186 -206.794632  141.817047
# 999  1790.243641  2313.009872  4398.177555  0.061076 -217.636307  112.630753
#
#      ...     mfcc11     mfcc12    mfcc13    mfcc14    mfcc15     mfcc16
# 0    ...   3.853339  -0.841709  2.132197  1.083205 -0.077104   0.648073  \
# 1    ...   3.662518   2.602134  4.048971  2.384604  1.780818  -2.392593
# 2    ...  -3.447254   0.874806 -1.936897 -2.783130 -2.666644  -3.311479
# 3    ...   3.856647  -0.844541  2.099680  1.122588  0.006671   0.748260
# 4    ...  -2.697902  -0.441958 -1.084060 -3.450706 -2.475977  -3.302751
# ..   ...        ...        ...       ...       ...       ...        ...
# 995  ... -10.986871  11.923828 -3.433859  7.191704 -8.850466   4.982307
# 996  ...  -3.630606  -5.505905  0.538993 -0.509386 -4.806393 -11.206601
# 997  ...   6.401213   3.414421 -2.899613  3.227199 -1.338827   0.875506
# 998  ...  -7.660741  -1.378526 -9.349154 -7.501380 -2.871112  -6.142300
# 999  ... -10.015160   9.042705 -6.878432  7.313042 -4.784163   8.559465
#
#        mfcc17    mfcc18    mfcc19     mfcc20
# 0   -1.484534  3.725630  4.553656   4.274244
# 1   -1.346176 -2.879179 -0.849864  -2.598134
# 2    1.708261 -0.152766  4.846820   2.906235
# 3   -1.474304  3.672843  4.469373   4.198666
# 4   -2.228499 -2.649556 -2.744086   0.305748
# ..        ...       ...       ...        ...
# 995 -4.036403 -0.111063 -0.818210  -0.612190
# 996 -3.936800 -1.469241 -4.413507 -10.597857
# 997  3.679272  0.648434 -0.353716   6.321081
# 998 -0.939825 -1.298267 -2.241966  -3.270761
# 999 -2.779625  1.276796 -0.356219   0.349866
#
# [1000 rows x 28 columns]

# %%
labels = df_all['filename'].str.split('.')
labels
# Out:
# 0       [pop, 00080, au]
# 1       [pop, 00022, au]
# 2       [pop, 00073, au]
# 3       [pop, 00047, au]
# 4       [pop, 00016, au]
#              ...
# 995    [jazz, 00027, au]
# 996    [jazz, 00076, au]
# 997    [jazz, 00085, au]
# 998    [jazz, 00042, au]
# 999    [jazz, 00013, au]
# Name: filename, Length: 1000, dtype: object

# %%
df_all['label'] = labels.str.get(0)

# %%
df_all['label'].unique(),len(df_all['label'].unique())
# Out:
# (array(['pop', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock',
#         'hiphop', 'country', 'jazz'], dtype=object),
#  10)

# %%
df_all.to_csv("./data/originalfile.csv",index=False)

# %%
# 데이터 불러오기
df2 = pd.read_csv("./data/originalfile.csv")
df2.head()
# Out:
#                              path      filename  chroma_stft      rmse
# 0  ./data/genres/pop/pop.00080.au  pop.00080.au     0.433540  0.215662  \
# 1  ./data/genres/pop/pop.00022.au  pop.00022.au     0.386972  0.196038
# 2  ./data/genres/pop/pop.00073.au  pop.00073.au     0.423550  0.259782
# 3  ./data/genres/pop/pop.00047.au  pop.00047.au     0.433407  0.215733
# 4  ./data/genres/pop/pop.00016.au  pop.00016.au     0.388811  0.146568
#
#      spec_cent      spec_bw      rolloff       zcr      mfcc1      mfcc2  ...
# 0  3151.406048  3220.623382  7294.559912  0.127557 -44.986890  69.775894  ...  \
# 1  3206.647959  3126.207007  7019.799238  0.141531 -45.730503  65.273964  ...
# 2  3669.810467  3295.063699  7876.372739  0.161797  -8.573006  54.295788  ...
# 3  3151.342623  3220.369559  7293.569019  0.127355 -45.029280  69.754700  ...
# 4  3488.897943  3205.348889  7496.760520  0.153314 -97.053980  51.834522  ...
#
#      mfcc12    mfcc13    mfcc14    mfcc15    mfcc16    mfcc17    mfcc18
# 0 -0.841709  2.132197  1.083206 -0.077104  0.648073 -1.484534  3.725630  \
# 1  2.602134  4.048971  2.384604  1.780818 -2.392593 -1.346176 -2.879179
# 2  0.874806 -1.936897 -2.783130 -2.666644 -3.311479  1.708261 -0.152766
# 3 -0.844541  2.099680  1.122588  0.006671  0.748260 -1.474304  3.672843
# 4 -0.441958 -1.084060 -3.450706 -2.475977 -3.302751 -2.228499 -2.649556
#
#      mfcc19    mfcc20  label
# 0  4.553656  4.274244    pop
# 1 -0.849864 -2.598134    pop
# 2  4.846820  2.906235    pop
# 3  4.469373  4.198666    pop
# 4 -2.744086  0.305748    pop
#
# [5 rows x 29 columns]
